# %% [markdown]
# ## RagAssistant

# %% [markdown]
# #### Dependendecies

# %%
! pip install swarmauri[full]==0.1.88
# Out:
# Requirement already satisfied: swarmauri==0.1.88 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.88) (0.1.88)
# Requirement already satisfied: numpy in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri==0.1.88->swarmauri[full]==0.1.88) (1.26.4)
# Requirement already satisfied: requests in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri==0.1.88->swarmauri[full]==0.1.88) (2.31.0)
# Requirement already satisfied: openai in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.88) (1.14.1)
# Requirement already satisfied: transformers in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.88) (4.40.1)
# Requirement already satisfied: accelerate in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.88) (0.28.0)
# Requirement already satisfied: tensorflow in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.88) (2.11.1)
# Requirement already satisfied: scipy in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.88) (1.10.0)
# Requirement already satisfied: typing-extensions in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.88) (4.10.0)
# Requirement already satisfied: redisearch in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.88) (2.1.1)
# Requirement already satisfied: google-api-python-client in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.88) (2.122.0)
# Requirement already satisfied: google-auth-httplib2 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.88) (0.2.0)
# Requirement already satisfied: google-auth-oauthlib in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.88) (0.4.6)
# Requirement already satisfied: boto3 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.88) (1.34.64)
# Requirement already satisfied: yake in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.88) (0.4.8)
# Requirement already satisfied: torch in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.88) (2.2.1+cu121)
# Requirement already satisfied: scikit-learn in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.88) (1.4.1.post1)
# Requirement already satisfied: gensim in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.88) (4.3.2)
# Requirement already satisfied: lightgbm in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.88) (4.3.0)
# Requirement already satisfied: rdflib in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.88) (7.0.0)
# Requirement already satisfied: textblob in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.88) (0.18.0.post0)
# Requirement already satisfied: spacy==3.7.4 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.88) (3.7.4)
# Requirement already satisfied: pygments in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.88) (2.17.2)
# Requirement already satisfied: stanford-openie in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.88) (1.3.2)
# Requirement already satisfied: sentencepiece in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.88) (0.2.0)
# Requirement already satisfied: gradio in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.88) (4.26.0)
# Requirement already satisfied: websockets in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.88) (11.0.3)
# Requirement already satisfied: groq in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.88) (0.5.0)
# Requirement already satisfied: mistralai in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.88) (0.1.8)
# Requirement already satisfied: cohere in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.88) (5.3.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.88) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.88) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.88) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.88) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.88) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.88) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.88) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.88) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.88) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.88) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.88) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.88) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.88) (4.66.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.88) (2.6.4)
# Requirement already satisfied: jinja2 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.88) (3.1.3)
# Requirement already satisfied: setuptools in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.88) (69.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.88) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.88) (3.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from requests->swarmauri==0.1.88->swarmauri[full]==0.1.88) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from requests->swarmauri==0.1.88->swarmauri[full]==0.1.88) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from requests->swarmauri==0.1.88->swarmauri[full]==0.1.88) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from requests->swarmauri==0.1.88->swarmauri[full]==0.1.88) (2024.2.2)
# Requirement already satisfied: psutil in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from accelerate->swarmauri[full]==0.1.88) (5.9.0)
# Requirement already satisfied: pyyaml in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from accelerate->swarmauri[full]==0.1.88) (6.0.1)
# Requirement already satisfied: huggingface-hub in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from accelerate->swarmauri[full]==0.1.88) (0.21.4)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from accelerate->swarmauri[full]==0.1.88) (0.4.2)
# Requirement already satisfied: filelock in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from torch->swarmauri[full]==0.1.88) (3.13.1)
# Requirement already satisfied: sympy in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from torch->swarmauri[full]==0.1.88) (1.12)
# Requirement already satisfied: networkx in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from torch->swarmauri[full]==0.1.88) (3.2.1)
# Requirement already satisfied: fsspec in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from torch->swarmauri[full]==0.1.88) (2024.3.0)
# Requirement already satisfied: botocore<1.35.0,>=1.34.64 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from boto3->swarmauri[full]==0.1.88) (1.34.64)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from boto3->swarmauri[full]==0.1.88) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from boto3->swarmauri[full]==0.1.88) (0.10.1)
# Requirement already satisfied: fastavro<2.0.0,>=1.9.4 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from cohere->swarmauri[full]==0.1.88) (1.9.4)
# Requirement already satisfied: httpx>=0.21.2 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from cohere->swarmauri[full]==0.1.88) (0.25.2)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from cohere->swarmauri[full]==0.1.88) (0.4.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from cohere->swarmauri[full]==0.1.88) (0.19.1)
# Requirement already satisfied: types-requests<3.0.0,>=2.0.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from cohere->swarmauri[full]==0.1.88) (2.31.0.20240406)
# Requirement already satisfied: httplib2<1.dev0,>=0.15.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from google-api-python-client->swarmauri[full]==0.1.88) (0.22.0)
# Requirement already satisfied: google-auth<3.0.0.dev0,>=1.19.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from google-api-python-client->swarmauri[full]==0.1.88) (2.28.2)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from google-api-python-client->swarmauri[full]==0.1.88) (2.17.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from google-api-python-client->swarmauri[full]==0.1.88) (4.1.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from google-auth-oauthlib->swarmauri[full]==0.1.88) (1.4.0)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.88) (23.2.1)
# Requirement already satisfied: altair<6.0,>=4.2.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.88) (5.3.0)
# Requirement already satisfied: fastapi in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.88) (0.110.1)
# Requirement already satisfied: ffmpy in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.88) (0.3.2)
# Requirement already satisfied: gradio-client==0.15.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.88) (0.15.1)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.88) (6.4.0)
# Requirement already satisfied: markupsafe~=2.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.88) (2.1.5)
# Requirement already satisfied: matplotlib~=3.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.88) (3.8.3)
# Requirement already satisfied: orjson~=3.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.88) (3.10.0)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.88) (2.2.1)
# Requirement already satisfied: pillow<11.0,>=8.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.88) (10.2.0)
# Requirement already satisfied: pydub in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.88) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.88) (0.0.9)
# Requirement already satisfied: ruff>=0.2.2 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.88) (0.3.7)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.88) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.88) (0.12.0)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.88) (0.29.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from groq->swarmauri[full]==0.1.88) (4.3.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from groq->swarmauri[full]==0.1.88) (1.9.0)
# Requirement already satisfied: sniffio in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from groq->swarmauri[full]==0.1.88) (1.3.1)
# Requirement already satisfied: isodate<0.7.0,>=0.6.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from rdflib->swarmauri[full]==0.1.88) (0.6.1)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from rdflib->swarmauri[full]==0.1.88) (3.1.2)
# Requirement already satisfied: hiredis<3.0.0,>=2.0.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from redisearch->swarmauri[full]==0.1.88) (2.3.2)
# Requirement already satisfied: redis==3.5.3 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from redisearch->swarmauri[full]==0.1.88) (3.5.3)
# Requirement already satisfied: rejson<0.6.0,>=0.5.4 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from redisearch->swarmauri[full]==0.1.88) (0.5.6)
# Requirement already satisfied: six<2.0.0,>=1.16.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from redisearch->swarmauri[full]==0.1.88) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from scikit-learn->swarmauri[full]==0.1.88) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from scikit-learn->swarmauri[full]==0.1.88) (3.3.0)
# Requirement already satisfied: wget in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from stanford-openie->swarmauri[full]==0.1.88) (3.2)
# Requirement already satisfied: stanfordnlp in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from stanford-openie->swarmauri[full]==0.1.88) (0.2.0)
# Requirement already satisfied: pydot in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from stanford-openie->swarmauri[full]==0.1.88) (2.0.0)
# Requirement already satisfied: protobuf<=3.20 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from stanford-openie->swarmauri[full]==0.1.88) (3.19.6)
# Requirement already satisfied: tensorflow-intel==2.11.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorflow->swarmauri[full]==0.1.88) (2.11.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.88) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.88) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.88) (24.3.7)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.88) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.88) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.88) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.88) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.88) (3.3.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.88) (2.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.88) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.88) (1.62.1)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.88) (2.11.2)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.88) (2.11.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.88) (2.11.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.88) (0.31.0)
# Requirement already satisfied: nltk>=3.8 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from textblob->swarmauri[full]==0.1.88) (3.8.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from transformers->swarmauri[full]==0.1.88) (2023.12.25)
# Requirement already satisfied: tabulate in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from yake->swarmauri[full]==0.1.88) (0.9.0)
# Requirement already satisfied: click>=6.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from yake->swarmauri[full]==0.1.88) (8.1.7)
# Requirement already satisfied: segtok in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from yake->swarmauri[full]==0.1.88) (1.5.11)
# Requirement already satisfied: jellyfish in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from yake->swarmauri[full]==0.1.88) (1.0.3)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from altair<6.0,>=4.2.0->gradio->swarmauri[full]==0.1.88) (4.19.2)
# Requirement already satisfied: toolz in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from altair<6.0,>=4.2.0->gradio->swarmauri[full]==0.1.88) (0.12.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from anyio<5,>=3.5.0->groq->swarmauri[full]==0.1.88) (1.2.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from botocore<1.35.0,>=1.34.64->boto3->swarmauri[full]==0.1.88) (2.9.0.post0)
# Requirement already satisfied: colorama in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from click>=6.0->yake->swarmauri[full]==0.1.88) (0.4.6)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client->swarmauri[full]==0.1.88) (1.63.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client->swarmauri[full]==0.1.88) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client->swarmauri[full]==0.1.88) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client->swarmauri[full]==0.1.88) (4.9)
# Requirement already satisfied: httpcore==1.* in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from httpx>=0.21.2->cohere->swarmauri[full]==0.1.88) (1.0.4)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from httpcore==1.*->httpx>=0.21.2->cohere->swarmauri[full]==0.1.88) (0.14.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from matplotlib~=3.0->gradio->swarmauri[full]==0.1.88) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from matplotlib~=3.0->gradio->swarmauri[full]==0.1.88) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from matplotlib~=3.0->gradio->swarmauri[full]==0.1.88) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from matplotlib~=3.0->gradio->swarmauri[full]==0.1.88) (1.4.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from pandas<3.0,>=1.0->gradio->swarmauri[full]==0.1.88) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from pandas<3.0,>=1.0->gradio->swarmauri[full]==0.1.88) (2024.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy==3.7.4->swarmauri[full]==0.1.88) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy==3.7.4->swarmauri[full]==0.1.88) (2.16.3)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->swarmauri[full]==0.1.88) (3.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy==3.7.4->swarmauri[full]==0.1.88) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy==3.7.4->swarmauri[full]==0.1.88) (0.1.4)
# Requirement already satisfied: shellingham<2.0.0,>=1.3.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from typer[all]<1.0,>=0.9; sys_platform != "emscripten"->gradio->swarmauri[full]==0.1.88) (1.5.4)
# Requirement already satisfied: rich<14.0.0,>=10.11.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from typer[all]<1.0,>=0.9; sys_platform != "emscripten"->gradio->swarmauri[full]==0.1.88) (13.7.1)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy==3.7.4->swarmauri[full]==0.1.88) (0.16.0)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from fastapi->gradio->swarmauri[full]==0.1.88) (0.37.2)
# Requirement already satisfied: mpmath>=0.19 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from sympy->torch->swarmauri[full]==0.1.88) (1.3.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.88) (0.43.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio->swarmauri[full]==0.1.88) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio->swarmauri[full]==0.1.88) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio->swarmauri[full]==0.1.88) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio->swarmauri[full]==0.1.88) (0.10.6)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client->swarmauri[full]==0.1.88) (0.5.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9; sys_platform != "emscripten"->gradio->swarmauri[full]==0.1.88) (2.2.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.88) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.88) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.88) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.88) (3.0.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9; sys_platform != "emscripten"->gradio->swarmauri[full]==0.1.88) (0.1.2)

# %%
from datetime import datetime
import sqlite3
import gradio as gr
import pandas as pd
import json
from typing import List, Dict
from swarmauri.standard.models.concrete.OpenAIModel import OpenAIModel
from swarmauri.standard.models.concrete.GroqModel import GroqModel
from swarmauri.standard.models.concrete.MistralModel import MistralModel
from swarmauri.standard.vector_stores.concrete.TFIDFVectorStore import TFIDFVectorStore
from swarmauri.standard.vector_stores.concrete.Doc2VecVectorStore import Doc2VecVectorStore
from swarmauri.standard.vector_stores.concrete.MLMVectorStore import MLMVectorStore
from swarmauri.standard.conversations.concrete.LimitedSystemContextConversation import LimitedSystemContextConversation
from swarmauri.standard.agents.concrete.RagAgent import RagAgent
from typing import Any, Optional, Union, Dict
from swarmauri.core.messages import IMessage
from swarmauri.core.models.IModel import IModel
from swarmauri.standard.conversations.base.SystemContextBase import SystemContextBase
from swarmauri.standard.agents.base.VectorStoreAgentBase import VectorStoreAgentBase
from swarmauri.standard.vector_stores.base.VectorDocumentStoreRetrieveBase import VectorDocumentStoreRetrieveBase
from swarmauri.standard.documents.concrete.Document import Document
from swarmauri.standard.documents.concrete.EmbeddedDocument import EmbeddedDocument
from swarmauri.standard.messages.concrete import (HumanMessage, 
                                                  SystemMessage,
                                                  AgentMessage)
from swarmauri.standard.utils.load_documents_from_json import load_documents_from_json_file
# Out:
# C:\Users\bigman\anaconda3\envs\swarmauri\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated and will be removed in a future release
#   "class": algorithms.Blowfish,

# %% [markdown]
# #### Project Class

# %%
head="""<link rel="icon" href="data:image/png;base64,..." type="image/png">"""

# %%
class RagAssistant:
    def __init__(self, api_key: str = "", db_path='prompt_responses.db', 
                 vector_store_path=None, model_name = "openai_gpt-4-0125-preview"):
        print('Initializing... this will take a moment.')
        self.api_key = api_key
        self.db_path = db_path
        self.conversation = LimitedSystemContextConversation(max_size=36, system_message_content="")
        self.allowed_models =sorted(['groq_llama3-8b-8192',
                            'groq_llama3-70b-8192',
                            'groq_mixtral-8x7b-32768',
                            'groq_gemma-7b-it',
                            'mistral_mistral-medium-latest',
                            'mistral_mistral-small-latest',
                            'mistral_open-mixtral-8x22b',
                            'mistral_open-mixtral-8x7b',
                            'mistral_open-mistral-7b',
                            'mistral_mistral-large-latest',
                            'openai_gpt-3.5-turbo',
                            'openai_gpt-3.5-turbo-16k',
                            'openai_gpt-4-0125-preview'
                              ])
            
        self.model = None
        self.retrieval_table = []
        self.document_table = []
        self.long_term_memory_df = None
        self.last_recall_df = None
        self.agent = self.initialize_agent()
        self.set_model(model_name)
        self.css = """
#chat-dialogue-container {
    min-height: 54vh !important;
}

#document-table-container {
    min-height: 80vh !important;
}

footer {
    display: none !important;
}
"""
        self.setup_gradio_interface()
        
    def initialize_agent(self):
        VS = Doc2VecVectorStore()
        agent = RagAgent(name="Rag", model=self.model, conversation=self.conversation, vector_store=VS)
        return agent

    def set_model(self, provider_model_choice: str):
        if provider_model_choice in self.allowed_models:
            provider, model_name = provider_model_choice.split('_')
            if provider == 'groq':
                self.model = GroqModel(api_key=self.api_key, model_name=model_name)
                
            if provider == 'mistral':
                self.model = MistralModel(api_key=self.api_key, model_name=model_name)
                
            if provider == 'openai':
                self.model = OpenAIModel(api_key=self.api_key, model_name=model_name)
                
            self.agent.model = self.model
                
        else:
            raise ValueError(f"Model name '{model_name}' is not supported. Choose from {self.allowed_models}")

    def change_vectorizer(self, vectorizer: str):
        if vectorizer == 'Doc2Vec':
            self.agent.vector_store = Doc2VecVectorStore()
        if vectorizer == 'MLM':
            self.agent.vector_store = MLMVectorStore()
        else:
            self.agent.vector_store = TFIDFVectorStore()
            
    
    def load_and_filter_json(self, file_info):
        # Load JSON file using json library
        try:
            documents = load_documents_from_json_file(file_info.name)
            self.agent.vector_store.documents = []
            self.agent.vector_store.add_documents(documents)
            self.long_term_memory_df = self.preprocess_documents(documents)
            return self.long_term_memory_df
        except json.JSONDecodeError:
            return "Invalid JSON file. Please check the file and try again."

    def preprocess_documents(self, documents):
        try:
            docs = [d.to_dict() for d in documents]
            for d in docs:
                metadata = d['metadata']
                for each in metadata:
                    d[each] = metadata[each]
                del d['metadata']
                del d['type']
                del d['embedding']
            df = pd.DataFrame.from_dict(docs)
            return df
        except Exception as e:
            print(f"postprocess_documents: {e}")

    
    def sql_log(self, conversation_id, model_name, prompt, response, start_datetime, end_datetime):
        try:
            duration = (end_datetime - start_datetime).total_seconds()
            start_datetime = start_datetime.isoformat()
            end_datetime = end_datetime.isoformat()
            conversation_id = str(conversation_id)
            conn = sqlite3.connect(self.db_path)
            cursor = conn.cursor()
            cursor.execute('''CREATE TABLE IF NOT EXISTS conversations
                            (id INTEGER PRIMARY KEY AUTOINCREMENT, 
                            conversation_id TEXT, 
                            model_name TEXT, 
                            prompt TEXT, 
                            response TEXT, 
                            start_datetime TEXT, 
                            end_datetime TEXT,
                            duration NUMERIC)''')
            cursor.execute('''INSERT INTO conversations (
                            conversation_id, 
                            model_name, 
                            prompt, 
                            response, 
                            start_datetime, 
                            end_datetime,
                            duration) VALUES (?, ?, ?, ?, ?, ?, ?)''', 
                           (conversation_id, 
                            model_name, 
                            prompt, 
                            response, 
                            start_datetime, 
                            end_datetime, 
                            duration))
            conn.commit()
            conn.close()
        except:
            raise
    
    def save_df(self, df):
        documents = self.dataframe_to_documents(df)
        self.agent.vector_store.documents = []
        self.agent.vector_store.add_documents(documents)
        self.long_term_memory_df = self.preprocess_documents(documents)
        return self.long_term_memory_df

    def dataframe_to_documents(self, df):
        documents = []
        for index, row in df.iterrows():
            row_dict = row.to_dict() 
            id = row_dict.pop("id", "")
            content = row_dict.pop("content", "")
            metadata = row_dict  # remaining data becomes metadata
        
            # Convert the row to dictionary and create a DocumentBase instance
            
            document = EmbeddedDocument(id=id, content=content, metadata=metadata)
            documents.append(document)
        return documents
    
    async def chatbot_function(self, 
                         message, 
                         history, 
                         api_key: str = None, 
                         model_name: str = None, 
                         top_k: int = 5, 
                         temperature: int = 1, 
                         max_tokens: int = 256):
        try:
            start_datetime = datetime.now()
            if self.agent.vector_store.document_count() == 0:
                return "", [], [(message, "⚠️ Add Documents First")]
            else:

                
                
                # Set additional parameters
                self.api_key = api_key
                self.set_model(model_name)
                
                
                
                # Predict
                response = self.agent.exec(message, top_k=top_k, model_kwargs={'temperature': temperature, 'max_tokens': max_tokens})
                
    
                # Update Retrieval Document Table
                self.last_recall_df = self.preprocess_documents(self.agent.last_similar_documents)
                
                # Get History
                history = [each['content'] for each in self.agent.conversation.to_dict()][1:]
                history = [(history[i], history[i+1]) for i in range(0, len(history), 2)]

                end_datetime = datetime.now()
                self.sql_log(self.agent.conversation.id, model_name, message, response, start_datetime, end_datetime)
                return "", self.last_recall_df, history
        except Exception as e:
            gr.Error(f"{e}")
            print(f"chatbot_function error: {e}")
            return "", [], history
    
    def clear_chat(self):
        # We could clear, but if we create a new instance, we get a new conversation id
        self.conversation = LimitedSystemContextConversation(max_size=36, system_message_content="")
        self.agent.conversation = self.conversation
        return "", [], []
        
    def setup_gradio_interface(self):
        with gr.Blocks(css=self.css) as self.retrieval_table:
            with gr.Row():
                self.retrieval_table = gr.Dataframe(interactive=False, wrap=True, line_breaks=True, elem_id="document-table-container", height="800")

        
        with gr.Blocks(css=self.css) as self.chat:
            with gr.Row():
                self.chat_history = gr.Chatbot(label="Chat History", 
                                           layout="panel", 
                                           elem_id="chat-dialogue-container", 
                                           container=True, 
                                           show_copy_button=True,
                                           height="70vh")
            with gr.Row():
                self.input_box = gr.Textbox(label="Type here:", scale=6)
                self.send_button = gr.Button("Send", scale=1)
                self.clear_button = gr.Button("Clear", scale=1)
                
            with gr.Accordion("See Details", open=False):
                self.additional_inputs = [
                    gr.Textbox(label="API Key", value=self.api_key or "Enter your API Key"),
                    gr.Dropdown(self.allowed_models, 
                                value="openai_gpt-3.5-turbo", 
                                label="Model",
                                info="Select openai model"),
                    gr.Slider(label="Top K", value=10, minimum=0, maximum=100, step=5, interactive=True),
                    gr.Slider(label="Temperature", value=1, minimum=0.0, maximum=1.5, step=0.05, interactive=True),
                    gr.Slider(label="Max new tokens", value=256, minimum=256, maximum=4096, step=64, interactive=True)
                ]
    
    
            submit_inputs = [self.input_box, self.chat_history]
            submit_inputs.extend(self.additional_inputs)
            # Function to handle sending messages
            self.send_button.click(
                self.chatbot_function, 
                inputs=submit_inputs, 
                outputs=[self.input_box, self.retrieval_table, self.chat_history]
            )
        
            # Function to handle clearing the chat
            self.clear_button.click(
                self.clear_chat, 
                inputs=[], 
                outputs=[self.input_box, self.retrieval_table, self.chat_history]
            )

        
        with gr.Blocks(css=self.css) as self.document_table:
            with gr.Row():
                self.file = gr.File(label="Upload JSON File")
                self.vectorizer = gr.Dropdown(choices=["Doc2Vec", "TFIDF", "MLM"], value="Doc2Vec", label="Select vectorizer")
                self.load_button = gr.Button("load")
            with gr.Row():
                self.data_frame = gr.Dataframe(interactive=True, wrap=True, line_breaks=True, elem_id="document-table-container", height="800")
            with gr.Row():
                self.save_button = gr.Button("save")
                
            self.vectorizer.change(self.change_vectorizer, inputs=[self.vectorizer], outputs=self.data_frame)
            self.load_button.click(self.load_and_filter_json, inputs=[self.file], outputs=self.data_frame)
            self.save_button.click(self.save_df, inputs=[self.data_frame])


       
        self.app = gr.TabbedInterface(interface_list=[self.chat, self.retrieval_table, self.document_table], 
                                      tab_names=["chat", "retrieval", "documents"], 
                                      title="Swarmauri Rag Agent",
                                      head=head)

    
    def launch(self):
        self.app.launch(share=False)

if __name__ == "__main__":
    rag_assistant = RagAssistant(db_path="E:\\swarmauri_github\\prompt_responses.db")
    rag_assistant.launch()
# Out:
# Initializing... this will take a moment.
# Running on local URL:  http://127.0.0.1:7868
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7868/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# <swarmauri.standard.models.concrete.GroqModel.GroqModel object at 0x000002505FF1BCD0> gemma-7b-it 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
# <swarmauri.standard.models.concrete.GroqModel.GroqModel object at 0x000002505FC636A0> gemma-7b-it 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
# <swarmauri.standard.models.concrete.GroqModel.GroqModel object at 0x000002505FC60400> gemma-7b-it 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
# <swarmauri.standard.models.concrete.GroqModel.GroqModel object at 0x000002505FC61750> gemma-7b-it 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
# <swarmauri.standard.models.concrete.GroqModel.GroqModel object at 0x000002505FE59F30> gemma-7b-it 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
# <swarmauri.standard.models.concrete.GroqModel.GroqModel object at 0x000002505FC6A0B0> gemma-7b-it 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
# <swarmauri.standard.models.concrete.GroqModel.GroqModel object at 0x000002505FF1BD30> gemma-7b-it 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
# <swarmauri.standard.models.concrete.GroqModel.GroqModel object at 0x000002505FC61BD0> gemma-7b-it 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
# <swarmauri.standard.models.concrete.GroqModel.GroqModel object at 0x000002505FBD04F0> gemma-7b-it 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
# <swarmauri.standard.models.concrete.GroqModel.GroqModel object at 0x000002505FC61810> gemma-7b-it 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
# <swarmauri.standard.models.concrete.GroqModel.GroqModel object at 0x000002505FC4A680> gemma-7b-it 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
# <swarmauri.standard.models.concrete.GroqModel.GroqModel object at 0x000002505FBD38B0> gemma-7b-it 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
# <swarmauri.standard.models.concrete.GroqModel.GroqModel object at 0x000002505FC61C60> gemma-7b-it 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
# <swarmauri.standard.models.concrete.GroqModel.GroqModel object at 0x000002505FBDC4C0> gemma-7b-it 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
# <swarmauri.standard.models.concrete.GroqModel.GroqModel object at 0x000002505FBDC760> gemma-7b-it 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
# <swarmauri.standard.models.concrete.GroqModel.GroqModel object at 0x000002505FBD1B40> gemma-7b-it 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
# <swarmauri.standard.models.concrete.GroqModel.GroqModel object at 0x000002505FBDF550> gemma-7b-it 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
# <swarmauri.standard.models.concrete.GroqModel.GroqModel object at 0x000002505FBB1D50> gemma-7b-it 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
# <swarmauri.standard.models.concrete.GroqModel.GroqModel object at 0x000002505FC606A0> gemma-7b-it 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
# <swarmauri.standard.models.concrete.GroqModel.GroqModel object at 0x000002505FBD3850> gemma-7b-it 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
# <swarmauri.standard.models.concrete.GroqModel.GroqModel object at 0x000002505FC616F0> gemma-7b-it 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
# <swarmauri.standard.models.concrete.GroqModel.GroqModel object at 0x000002505FB76650> gemma-7b-it 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
# <swarmauri.standard.models.concrete.GroqModel.GroqModel object at 0x000002505F5521D0> gemma-7b-it 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
# <swarmauri.standard.models.concrete.GroqModel.GroqModel object at 0x000002505FBB03D0> gemma-7b-it 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
# <swarmauri.standard.models.concrete.GroqModel.GroqModel object at 0x000002505FE5ADD0> gemma-7b-it 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
# <swarmauri.standard.models.concrete.GroqModel.GroqModel object at 0x000002505F5508B0> gemma-7b-it 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
# <swarmauri.standard.models.concrete.GroqModel.GroqModel object at 0x000002505FE59A20> gemma-7b-it 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
# <swarmauri.standard.models.concrete.GroqModel.GroqModel object at 0x000002505FBB2290> gemma-7b-it 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

# %%
import json
from typing import List
from groq import Groq
from swarmauri.core.models.IPredict import IPredict
from swarmauri.standard.models.base.ModelBase import ModelBase


class GroqModel2(ModelBase, IPredict):
    allowed_models = ['llama3-8b-8192', 'llama3-70b-8192', 'mixtral-8x7b-32768', 'gemma-7b-it']

    def __init__(self, api_key: str, model_name: str = 'mixtral-8x7b-32768'):
        if model_name not in self.allowed_models:
            raise ValueError(f"Model name '{model_name}' is not supported. Choose from {self.allowed_models}")
        
        self.client = Groq(api_key=api_key)
        super().__init__(model_name)
        
    
    def predict(self, messages, temperature=0.7, max_tokens=256, enable_json=False, stop: List[str] = None):
        if self.client is None:
            raise Exception("GroqModel client is not initialized. Call 'load_model' first.")
        
        if enable_json:
            response = self.client.chat.completions.create(
                model=self.model_name,
                messages=messages,
                temperature=temperature,
                response_format={ "type": "json_object" },
                max_tokens=max_tokens,
                top_p=1,
                frequency_penalty=0,
                presence_penalty=0,
                stop=stop, 
                stream=True
            )
        else:
            response = self.client.chat.completions.create(
                model=self.model_name,
                messages=messages,
                temperature=temperature,
                max_tokens=max_tokens,
                top_p=1,
                frequency_penalty=0,
                presence_penalty=0,
                stop=stop,
                stream=True
            )
        for chunk in response:
            if chunk.choices[0].delta.content:
                yield chunk.choices[0].delta.content
            
        
        return response

# %%
a=GroqModel2(api_key='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', model_name='llama3-8b-8192')

# %%
res = a.predict([{"role":"user", "content": "tell me a bed time story"}])
while True:
    print(next(res))
# Out:
# Here
# 's
#  a
#  bedtime
#  story
#  for
#  you
# :
#
#
# Once
#  upon
#  a
#  time
# ,
#  in
#  a
#  land
#  far
# ,
#  far
#  away
# ,
#  there
#  was
#  a
#  magical
#  forest
#  filled
#  with
#  towering
#  trees
# ,
#  sparkling
#  streams
# ,
#  and
#  a
#  vast
#  array
#  of
#  creatures
# .
#  Among
#  the
#  trees
#  lived
#  a
#  little
#  rabbit
#  named
#  Rosie
# .
#  Rosie
#  was
#  a
#  curious
#  and
#  adventurous
#  bunny
#  who
#  loved
#  to
#  explore
#  the
#  forest
# ,
#  discovering
#  hidden
#  clear
# ings
# ,
#  secret
#  water
# falls
# ,
#  and
#  hidden
#  caves
# .
#
#
# One
#  day
# ,
#  while
#  wandering
#  through
#  the
#  forest
# ,
#  Rosie
#  stumbled
#  upon
#  a
#  hidden
#  gl
# ade
# .
#  In
#  the
#  center
#  of
#  the
#  gl
# ade
#  stood
#  an
#  enormous
# ,
#  ancient
#  tree
# ,
#  its
#  trunk
#  twisted
#  and
#  gn
# ar
# led
#  with
#  age
# .
#  Car
# ved
#  into
#  the
#  trunk
#  was
#  a
#  door
# ,
#  adorned
#  with
#  intricate
#  car
# v
# ings
#  of
#  leaves
# ,
#  flowers
# ,
#  and
#  stars
# .
#  Rosie
# 's
#  curiosity
#  got
#  the
#  better
#  of
#  her
# ,
#  and
#  she
#  decided
#  to
#  investigate
# .
#
#
# As
#  she
#  approached
#  the
#  door
# ,
#  it
#  swung
#  open
#  with
#  a
#  soft
#  c
# reak
# ,
#  revealing
#  a
#  cozy
#  room
#  filled
#  with
#  plush
#  moss
# ,
#  soft
#  feathers
# ,
#  and
#  the
#  most
#  comfortable
# -looking
#  pillows
#  Rosie
#  had
#  ever
#  seen
# .
#  A
#  gentle
#  voice
#  whispered
# ,
#  "
# Welcome
# ,
#  little
#  one
# .
#  I
# 've
#  been
#  waiting
#  for
#  you
# ."
#
#
# Ros
# ie
# 's
#  eyes
#  grew
#  wide
#  as
#  she
#  explored
#  the
#  room
# ,
#  discovering
#  all
#  sorts
#  of
#  treasures
# :
#  shiny
#  gem
# stones
# ,
#  sparkling
#  crystals
# ,
#  and
#  a
#  magnificent
# ,
#  shimmer
# ing
#  star
#  that
#  hung
#  from
#  the
#  ceiling
#  like
#  a
#  ch
# andelier
# .
#  Suddenly
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[6], line 3
#       1 res = a.predict([{"role":"user", "content": "tell me a bed time story"}])
#       2 while True:
# ----> 3     print(next(res))
#
# StopIteration: <groq.Stream object at 0x00000226E4DE96C0>

# %%
# Out:
# 's
