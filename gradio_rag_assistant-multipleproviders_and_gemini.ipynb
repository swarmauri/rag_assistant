# %% [markdown]
# ## RagAssistant

# %% [markdown]
# #### Dependendecies

# %%
! pip install swarmauri[full]==0.1.106
# Out:
# Collecting swarmauri==0.1.106 (from swarmauri[full]==0.1.106)
#   Downloading swarmauri-0.1.106-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: numpy in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri==0.1.106->swarmauri[full]==0.1.106) (1.26.4)
# Requirement already satisfied: requests in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri==0.1.106->swarmauri[full]==0.1.106) (2.31.0)
# Requirement already satisfied: openai in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.106) (1.14.1)
# Requirement already satisfied: transformers in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.106) (4.40.1)
# Requirement already satisfied: tensorflow in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.106) (2.11.1)
# Requirement already satisfied: scipy in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.106) (1.10.0)
# Requirement already satisfied: typing-extensions in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.106) (4.10.0)
# Requirement already satisfied: redisearch in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.106) (2.1.1)
# Requirement already satisfied: google-api-python-client in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.106) (2.122.0)
# Requirement already satisfied: google-auth-httplib2 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.106) (0.2.0)
# Requirement already satisfied: google-auth-oauthlib in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.106) (0.4.6)
# Requirement already satisfied: boto3 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.106) (1.34.64)
# Requirement already satisfied: torch in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.106) (2.2.1+cu121)
# Requirement already satisfied: scikit-learn in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.106) (1.4.1.post1)
# Requirement already satisfied: gensim in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.106) (4.3.2)
# Requirement already satisfied: textblob in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.106) (0.18.0.post0)
# Requirement already satisfied: spacy==3.7.4 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.106) (3.7.4)
# Requirement already satisfied: pygments in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.106) (2.17.2)
# Requirement already satisfied: gradio in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.106) (4.26.0)
# Requirement already satisfied: websockets in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.106) (11.0.3)
# Requirement already satisfied: groq in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.106) (0.5.0)
# Requirement already satisfied: mistralai in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.106) (0.1.8)
# Requirement already satisfied: cohere in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.106) (5.3.3)
# Requirement already satisfied: google-generativeai in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.106) (0.5.2)
# Requirement already satisfied: anthropic in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.106) (0.25.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.106) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.106) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.106) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.106) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.106) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.106) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.106) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.106) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.106) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.106) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.106) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.106) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.106) (4.66.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.106) (2.6.4)
# Requirement already satisfied: jinja2 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.106) (3.1.3)
# Requirement already satisfied: setuptools in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.106) (69.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.106) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.106) (3.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from requests->swarmauri==0.1.106->swarmauri[full]==0.1.106) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from requests->swarmauri==0.1.106->swarmauri[full]==0.1.106) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from requests->swarmauri==0.1.106->swarmauri[full]==0.1.106) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from requests->swarmauri==0.1.106->swarmauri[full]==0.1.106) (2024.2.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from anthropic->swarmauri[full]==0.1.106) (4.3.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from anthropic->swarmauri[full]==0.1.106) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from anthropic->swarmauri[full]==0.1.106) (0.25.2)
# Requirement already satisfied: sniffio in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from anthropic->swarmauri[full]==0.1.106) (1.3.1)
# Requirement already satisfied: tokenizers>=0.13.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from anthropic->swarmauri[full]==0.1.106) (0.19.1)
# Requirement already satisfied: botocore<1.35.0,>=1.34.64 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from boto3->swarmauri[full]==0.1.106) (1.34.64)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from boto3->swarmauri[full]==0.1.106) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from boto3->swarmauri[full]==0.1.106) (0.10.1)
# Requirement already satisfied: fastavro<2.0.0,>=1.9.4 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from cohere->swarmauri[full]==0.1.106) (1.9.4)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from cohere->swarmauri[full]==0.1.106) (0.4.0)
# Requirement already satisfied: types-requests<3.0.0,>=2.0.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from cohere->swarmauri[full]==0.1.106) (2.31.0.20240406)
# Requirement already satisfied: httplib2<1.dev0,>=0.15.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from google-api-python-client->swarmauri[full]==0.1.106) (0.22.0)
# Requirement already satisfied: google-auth<3.0.0.dev0,>=1.19.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from google-api-python-client->swarmauri[full]==0.1.106) (2.28.2)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from google-api-python-client->swarmauri[full]==0.1.106) (2.17.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from google-api-python-client->swarmauri[full]==0.1.106) (4.1.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from google-auth-oauthlib->swarmauri[full]==0.1.106) (1.4.0)
# Requirement already satisfied: google-ai-generativelanguage==0.6.2 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from google-generativeai->swarmauri[full]==0.1.106) (0.6.2)
# Requirement already satisfied: protobuf in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from google-generativeai->swarmauri[full]==0.1.106) (3.19.6)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from google-ai-generativelanguage==0.6.2->google-generativeai->swarmauri[full]==0.1.106) (1.23.0)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.106) (23.2.1)
# Requirement already satisfied: altair<6.0,>=4.2.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.106) (5.3.0)
# Requirement already satisfied: fastapi in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.106) (0.110.1)
# Requirement already satisfied: ffmpy in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.106) (0.3.2)
# Requirement already satisfied: gradio-client==0.15.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.106) (0.15.1)
# Requirement already satisfied: huggingface-hub>=0.19.3 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.106) (0.21.4)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.106) (6.4.0)
# Requirement already satisfied: markupsafe~=2.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.106) (2.1.5)
# Requirement already satisfied: matplotlib~=3.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.106) (3.8.3)
# Requirement already satisfied: orjson~=3.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.106) (3.10.0)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.106) (2.2.1)
# Requirement already satisfied: pillow<11.0,>=8.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.106) (10.2.0)
# Requirement already satisfied: pydub in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.106) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.106) (0.0.9)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.106) (6.0.1)
# Requirement already satisfied: ruff>=0.2.2 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.106) (0.3.7)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.106) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.106) (0.12.0)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.106) (0.29.0)
# Requirement already satisfied: fsspec in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio-client==0.15.1->gradio->swarmauri[full]==0.1.106) (2024.3.0)
# Requirement already satisfied: hiredis<3.0.0,>=2.0.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from redisearch->swarmauri[full]==0.1.106) (2.3.2)
# Requirement already satisfied: redis==3.5.3 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from redisearch->swarmauri[full]==0.1.106) (3.5.3)
# Requirement already satisfied: rejson<0.6.0,>=0.5.4 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from redisearch->swarmauri[full]==0.1.106) (0.5.6)
# Requirement already satisfied: six<2.0.0,>=1.16.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from redisearch->swarmauri[full]==0.1.106) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from scikit-learn->swarmauri[full]==0.1.106) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from scikit-learn->swarmauri[full]==0.1.106) (3.3.0)
# Requirement already satisfied: tensorflow-intel==2.11.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorflow->swarmauri[full]==0.1.106) (2.11.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.106) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.106) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.106) (24.3.7)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.106) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.106) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.106) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.106) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.106) (3.3.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.106) (2.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.106) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.106) (1.62.1)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.106) (2.11.2)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.106) (2.11.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.106) (2.11.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.106) (0.31.0)
# Requirement already satisfied: nltk>=3.8 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from textblob->swarmauri[full]==0.1.106) (3.8.1)
# Requirement already satisfied: filelock in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from torch->swarmauri[full]==0.1.106) (3.13.1)
# Requirement already satisfied: sympy in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from torch->swarmauri[full]==0.1.106) (1.12)
# Requirement already satisfied: networkx in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from torch->swarmauri[full]==0.1.106) (3.2.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from transformers->swarmauri[full]==0.1.106) (2023.12.25)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from transformers->swarmauri[full]==0.1.106) (0.4.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from altair<6.0,>=4.2.0->gradio->swarmauri[full]==0.1.106) (4.19.2)
# Requirement already satisfied: toolz in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from altair<6.0,>=4.2.0->gradio->swarmauri[full]==0.1.106) (0.12.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from anyio<5,>=3.5.0->anthropic->swarmauri[full]==0.1.106) (1.2.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from botocore<1.35.0,>=1.34.64->boto3->swarmauri[full]==0.1.106) (2.9.0.post0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client->swarmauri[full]==0.1.106) (1.63.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client->swarmauri[full]==0.1.106) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client->swarmauri[full]==0.1.106) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client->swarmauri[full]==0.1.106) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from httplib2<1.dev0,>=0.15.0->google-api-python-client->swarmauri[full]==0.1.106) (3.1.2)
# Requirement already satisfied: httpcore==1.* in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from httpx<1,>=0.23.0->anthropic->swarmauri[full]==0.1.106) (1.0.4)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->anthropic->swarmauri[full]==0.1.106) (0.14.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from matplotlib~=3.0->gradio->swarmauri[full]==0.1.106) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from matplotlib~=3.0->gradio->swarmauri[full]==0.1.106) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from matplotlib~=3.0->gradio->swarmauri[full]==0.1.106) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from matplotlib~=3.0->gradio->swarmauri[full]==0.1.106) (1.4.5)
# Requirement already satisfied: click in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from nltk>=3.8->textblob->swarmauri[full]==0.1.106) (8.1.7)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from pandas<3.0,>=1.0->gradio->swarmauri[full]==0.1.106) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from pandas<3.0,>=1.0->gradio->swarmauri[full]==0.1.106) (2024.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy==3.7.4->swarmauri[full]==0.1.106) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy==3.7.4->swarmauri[full]==0.1.106) (2.16.3)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->swarmauri[full]==0.1.106) (3.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy==3.7.4->swarmauri[full]==0.1.106) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy==3.7.4->swarmauri[full]==0.1.106) (0.1.4)
# Requirement already satisfied: colorama in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy==3.7.4->swarmauri[full]==0.1.106) (0.4.6)
# Requirement already satisfied: shellingham<2.0.0,>=1.3.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from typer[all]<1.0,>=0.9; sys_platform != "emscripten"->gradio->swarmauri[full]==0.1.106) (1.5.4)
# Requirement already satisfied: rich<14.0.0,>=10.11.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from typer[all]<1.0,>=0.9; sys_platform != "emscripten"->gradio->swarmauri[full]==0.1.106) (13.7.1)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy==3.7.4->swarmauri[full]==0.1.106) (0.16.0)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from fastapi->gradio->swarmauri[full]==0.1.106) (0.37.2)
# Requirement already satisfied: mpmath>=0.19 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from sympy->torch->swarmauri[full]==0.1.106) (1.3.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.106) (0.43.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.2->google-generativeai->swarmauri[full]==0.1.106) (1.48.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio->swarmauri[full]==0.1.106) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio->swarmauri[full]==0.1.106) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio->swarmauri[full]==0.1.106) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio->swarmauri[full]==0.1.106) (0.10.6)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client->swarmauri[full]==0.1.106) (0.5.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9; sys_platform != "emscripten"->gradio->swarmauri[full]==0.1.106) (2.2.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.106) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.106) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.106) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.106) (3.0.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9; sys_platform != "emscripten"->gradio->swarmauri[full]==0.1.106) (0.1.2)
# Downloading swarmauri-0.1.106-py3-none-any.whl (228 kB)
#    ---------------------------------------- 0.0/228.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/228.5 kB ? eta -:--:--
#    --- ------------------------------------ 20.5/228.5 kB ? eta -:--:--
#    -------- ------------------------------ 51.2/228.5 kB 871.5 kB/s eta 0:00:01
#    ---------------------------------------  225.3/228.5 kB 2.3 MB/s eta 0:00:01
#    ---------------------------------------- 228.5/228.5 kB 2.3 MB/s eta 0:00:00
# Installing collected packages: swarmauri
#   Attempting uninstall: swarmauri
#     Found existing installation: swarmauri 0.1.104
#     Uninstalling swarmauri-0.1.104:
#       Successfully uninstalled swarmauri-0.1.104
# Successfully installed swarmauri-0.1.106
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# swarmauri-developer 0.0.8 requires swarmauri[full]==0.1.80, but you have swarmauri 0.1.106 which is incompatible.

# %%
from datetime import datetime
import sqlite3
import gradio as gr
import pandas as pd
import json
from typing import Any, Optional, Union, Dict
from swarmauri.standard.models.concrete.OpenAIModel import OpenAIModel
from swarmauri.standard.models.concrete.GroqModel import GroqModel
from swarmauri.standard.models.concrete.MistralModel import MistralModel
from swarmauri.standard.models.concrete.GeminiProModel import GeminiProModel
from swarmauri.standard.models.concrete.AnthropicModel import AnthropicModel
from swarmauri.standard.vector_stores.concrete.TFIDFVectorStore import TFIDFVectorStore
from swarmauri.standard.vector_stores.concrete.Doc2VecVectorStore import Doc2VecVectorStore
from swarmauri.standard.vector_stores.concrete.MLMVectorStore import MLMVectorStore
from swarmauri.standard.conversations.concrete.SessionCacheConversation import SessionCacheConversation
from swarmauri.standard.agents.concrete.RagAgent import RagAgent
from swarmauri.core.messages import IMessage
from swarmauri.core.models.IModel import IModel
from swarmauri.standard.conversations.base.SystemContextBase import SystemContextBase
from swarmauri.standard.agents.base.VectorStoreAgentBase import VectorStoreAgentBase
from swarmauri.standard.vector_stores.base.VectorDocumentStoreRetrieveBase import VectorDocumentStoreRetrieveBase
from swarmauri.standard.documents.concrete.Document import Document
from swarmauri.standard.documents.concrete.EmbeddedDocument import EmbeddedDocument
from swarmauri.standard.messages.concrete import (HumanMessage, 
                                                  SystemMessage,
                                                  AgentMessage)
from swarmauri.standard.utils.load_documents_from_json import load_documents_from_json_file

# %% [raw]
# import json
# from typing import List
# import google.generativeai as genai
# from swarmauri.core.models.IPredict import IPredict
# from swarmauri.standard.models.base.ModelBase import ModelBase
#
#
# class GeminiProModel(ModelBase, IPredict):
#     allowed_models = ['gemini-1.5-pro-latest']
#
#     def __init__(self, api_key: str, model_name: str = 'gemini-1.5-pro-latest'):
#         if model_name not in self.allowed_models:
#             raise ValueError(f"Model name '{model_name}' is not supported. Choose from {self.allowed_models}")
#
#         genai.configure(api_key=api_key)
#         self.safety_settings = [
#           {
#             "category": "HARM_CATEGORY_HARASSMENT",
#             "threshold": "BLOCK_MEDIUM_AND_ABOVE"
#           },
#           {
#             "category": "HARM_CATEGORY_HATE_SPEECH",
#             "threshold": "BLOCK_MEDIUM_AND_ABOVE"
#           },
#           {
#             "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
#             "threshold": "BLOCK_MEDIUM_AND_ABOVE"
#           },
#           {
#             "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
#             "threshold": "BLOCK_MEDIUM_AND_ABOVE"
#           },
#         ]
#         self.safety_settings = [
#           {
#             "category": "HARM_CATEGORY_HARASSMENT",
#             "threshold": "BLOCK_MEDIUM_AND_ABOVE"
#           },
#           {
#             "category": "HARM_CATEGORY_HATE_SPEECH",
#             "threshold": "BLOCK_MEDIUM_AND_ABOVE"
#           },
#           {
#             "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
#             "threshold": "BLOCK_MEDIUM_AND_ABOVE"
#           },
#           {
#             "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
#             "threshold": "BLOCK_MEDIUM_AND_ABOVE"
#           },
#         ]
#         self.client = None
#         super().__init__(model_name)
#
#
#     def predict(self, messages, temperature=0.7, max_tokens=256):
#         generation_config = {
#             "temperature": temperature,
#             "top_p": 0.95,
#             "top_k": 0,
#             "max_output_tokens": max_tokens,
#             }
#
#         system_context = None
#         for message in messages:
#
#             # update role naming
#             role = message.pop('role')
#             if role == 'assistant':
#                 role = 'model'
#
#             if role == 'system':
#                 system_context = message['content']
#
#             # rename role
#             message['role'] = role
#
#             # update content naming
#             message['parts'] = message.pop('content')
#
#
#         # Remove system instruction from messages
#         sanitized_messages = [message for message in messages if message['role'] != 'system']
#
#         # if we remove more than one system message from the array
#         # then we know we were given too many system messages
#         # we raise an error in this scenario.
#         # Examples:
#         # 10 - 1 = 9 so if 9 + 1 < 10  then negative is good
#         # 10 - 2 = 8, so if 8 + 1 < 10 then positive is bad
#         if len(sanitized_messages) + 1 > len(messages):
#             raise ValueError('cannot send an array of conversations containing more than one system instruction.')
#
#
#         next_message = sanitized_messages.pop()
#
#         self.client = genai.GenerativeModel(model_name=self.model_name,
#             safety_settings=self.safety_settings,
#             generation_config=generation_config)
#
#         convo = self.client.start_chat(
#             history=sanitized_messages,
#             )
#
#         convo.send_message(next_message['parts'])
#
#         message_content = convo.last.text
#
#         return message_content

# %% [raw]
# import json
# from typing import List
# import anthropic
# from swarmauri.core.models.IPredict import IPredict
# from swarmauri.standard.models.base.ModelBase import ModelBase
#
#
# class AnthropicModel(ModelBase, IPredict):
#     allowed_models = ['claude-3-opus-20240229', 'claude-3-sonnet-20240229', 'claude-3-haiku-20240307']
#
#     def __init__(self, api_key: str, model_name: str = 'claude-3-haiku-20240307'):
#         if model_name not in self.allowed_models:
#             raise ValueError(f"Model name '{model_name}' is not supported. Choose from {self.allowed_models}")
#
#         self.client = anthropic.Anthropic(api_key=api_key)
#         super().__init__(model_name)
#
#
#     def predict(self, messages, temperature=0.7, max_tokens=256):
#
#
#
#         # Get system_context
#         system_context = None
#         for message in messages:
#             if message['role'] == 'system':
#                 print(message)
#                 system_context = message['content']
#                 print(message)
#
#         # Remove system instruction from messages
#         sanitized_messages = [message for message in messages if message['role'] != 'system']
#
#         # we should only remove one message for system instruction
#         if len(sanitized_messages) + 1 > len(messages):
#             raise ValueError('cannot send an array of conversations containing more than one system instruction.')
#
#         # Chat
#         response = self.client.messages.create(
#             model=self.model_name,
#             messages=sanitized_messages,
#             system=system_context,
#             temperature=temperature,
#             max_tokens=max_tokens
#         )
#         print('response', )
#         print('response.content', response.content)
#         print('response.content', response.content[0].text)
#
#
#         message_content = response.content[0].text
#         return message_content

# %% [markdown]
# #### Project Class

# %%
head="""<link rel="icon" href="data:image/png;base64,..." type="image/png">"""

# %%
class RagAssistant:
    def __init__(self, api_key: str = "", db_path='prompt_responses.db', 
                 vector_store_path=None, model_name = "openai_gpt-4-0125-preview"):
        print('Initializing... this will take a moment.')
        self.api_key = api_key
        self.db_path = db_path
        self.conversation = SessionCacheConversation(max_size=2, system_message_content="")
        self.allowed_models =sorted(['groq_llama3-8b-8192',
                            'groq_llama3-70b-8192',
                            'groq_mixtral-8x7b-32768',
                            'groq_gemma-7b-it',
                            'mistral_mistral-medium-latest',
                            'mistral_mistral-small-latest',
                            'mistral_open-mixtral-8x22b',
                            'mistral_open-mixtral-8x7b',
                            'mistral_open-mistral-7b',
                            'mistral_mistral-large-latest',
                            'openai_gpt-3.5-turbo',
                            'openai_gpt-3.5-turbo-16k',
                            'openai_gpt-4-0125-preview',
                            'google_gemini-1.5-pro-latest',
                            'anthropic_claude-3-opus-20240229',
                            'anthropic_claude-3-sonnet-20240229',
                            'anthropic_claude-3-haiku-20240307'])
            
        self.model = None
        self.retrieval_table = []
        self.document_table = []
        self.long_term_memory_df = None
        self.last_recall_df = None
        self.agent = self.initialize_agent()
        self.set_model(model_name)
        self.css = """
#chat-dialogue-container {
    min-height: 54vh !important;
}

#document-table-container {
    min-height: 80vh !important;
}

footer {
    display: none !important;
}
"""
        self.setup_gradio_interface()
        
    def initialize_agent(self):
        VS = Doc2VecVectorStore()
        agent = RagAgent(name="Rag", model=self.model, conversation=self.conversation, vector_store=VS)
        return agent

    def set_model(self, provider_model_choice: str):
        if provider_model_choice in self.allowed_models:
            provider, model_name = provider_model_choice.split('_')
            if provider == 'groq':
                self.model = GroqModel(api_key=self.api_key, model_name=model_name)
                
            if provider == 'mistral':
                self.model = MistralModel(api_key=self.api_key, model_name=model_name)
                
            if provider == 'openai':
                self.model = OpenAIModel(api_key=self.api_key, model_name=model_name)

            if provider == 'google':
                self.model = GeminiProModel(api_key=self.api_key, model_name=model_name)

            if provider == 'anthropic':
                self.model = AnthropicModel(api_key=self.api_key, model_name=model_name)
            
            self.agent.model = self.model
                
        else:
            raise ValueError(f"Model name '{model_name}' is not supported. Choose from {self.allowed_models}")

    def change_vectorizer(self, vectorizer: str):
        if vectorizer == 'Doc2Vec':
            self.agent.vector_store = Doc2VecVectorStore()
        if vectorizer == 'MLM':
            self.agent.vector_store = MLMVectorStore()
        else:
            self.agent.vector_store = TFIDFVectorStore()
            
    
    def load_and_filter_json(self, file_info):
        # Load JSON file using json library
        try:
            documents = load_documents_from_json_file(file_info.name)
            self.agent.vector_store.documents = []
            self.agent.vector_store.add_documents(documents)
            self.long_term_memory_df = self.preprocess_documents(documents)
            return self.long_term_memory_df
        except json.JSONDecodeError:
            return "Invalid JSON file. Please check the file and try again."

    def preprocess_documents(self, documents):
        try:
            docs = [d.to_dict() for d in documents]
            for d in docs:
                metadata = d['metadata']
                for each in metadata:
                    d[each] = metadata[each]
                del d['metadata']
                del d['type']
                del d['embedding']
            df = pd.DataFrame.from_dict(docs)
            return df
        except Exception as e:
            print(f"postprocess_documents: {e}")

    
    def sql_log(self, conversation_id, model_name, prompt, response, start_datetime, end_datetime):
        try:
            duration = (end_datetime - start_datetime).total_seconds()
            start_datetime = start_datetime.isoformat()
            end_datetime = end_datetime.isoformat()
            conversation_id = str(conversation_id)
            conn = sqlite3.connect(self.db_path)
            cursor = conn.cursor()
            cursor.execute('''CREATE TABLE IF NOT EXISTS conversations
                            (id INTEGER PRIMARY KEY AUTOINCREMENT, 
                            conversation_id TEXT, 
                            model_name TEXT, 
                            prompt TEXT, 
                            response TEXT, 
                            start_datetime TEXT, 
                            end_datetime TEXT,
                            duration NUMERIC)''')
            cursor.execute('''INSERT INTO conversations (
                            conversation_id, 
                            model_name, 
                            prompt, 
                            response, 
                            start_datetime, 
                            end_datetime,
                            duration) VALUES (?, ?, ?, ?, ?, ?, ?)''', 
                           (conversation_id, 
                            model_name, 
                            prompt, 
                            response, 
                            start_datetime, 
                            end_datetime, 
                            duration))
            conn.commit()
            conn.close()
        except:
            raise
    
    def save_df(self, df):
        documents = self.dataframe_to_documents(df)
        self.agent.vector_store.documents = []
        self.agent.vector_store.add_documents(documents)
        self.long_term_memory_df = self.preprocess_documents(documents)
        return self.long_term_memory_df

    def dataframe_to_documents(self, df):
        documents = []
        for index, row in df.iterrows():
            row_dict = row.to_dict() 
            id = row_dict.pop("id", "")
            content = row_dict.pop("content", "")
            metadata = row_dict  # remaining data becomes metadata
        
            # Convert the row to dictionary and create a DocumentBase instance
            
            document = EmbeddedDocument(id=id, content=content, metadata=metadata)
            documents.append(document)
        return documents
        
    def clear_chat(self):
        # We could clear, but if we create a new instance, we get a new conversation id
        max_size = self.agent.conversation.max_size
        session_cache_size = self.agent.conversation.session_cache_max_size
        self.conversation = SessionCacheConversation(max_size=max_size, 
                                                     system_message_content="", 
                                                     session_cache_max_size=session_cache_size)
        self.agent.conversation = self.conversation
        return "", [], []    
        
    async def chatbot_function(self, 
                         message, 
                         history, 
                         api_key: str = None, 
                         model_name: str = None, 
                         top_k: int = 5, 
                         temperature: int = 1, 
                         max_tokens: int = 256,
                         conversation_size: int = 2,
                         session_cache_size: int = 2):
        try:
            start_datetime = datetime.now()
            if self.agent.vector_store.document_count() == 0:
                return "", [], [(message, "⚠️ Add Documents First")]
            else:

                
                
                # Set additional parameters
                self.api_key = api_key
                self.set_model(model_name)
                #print(self.model, self.model.model_name, self.api_key)

                # Set Conversation Size
                self.agent.conversation.max_size = conversation_size
                self.agent.conversation.session_cache_max_size = session_cache_size
                
                # Predict
                response = self.agent.exec(message, top_k=top_k, model_kwargs={'temperature': temperature, 'max_tokens': max_tokens})
    
                # Update Retrieval Document Table
                self.last_recall_df = self.preprocess_documents(self.agent.last_similar_documents)
                
                # Get History
                history = [each['content'] for each in self.agent.conversation.session_to_dict()]
                history = [(history[i], history[i+1]) for i in range(0, len(history), 2)]

                # SQL Log
                end_datetime = datetime.now()
                self.sql_log(self.agent.conversation.id, model_name, message, response, start_datetime, end_datetime)
                
                return "", self.last_recall_df, history
        except Exception as e:
            gr.Error(f"{e}")
            self.agent.conversation._history.pop(0)
            print(f"chatbot_function error: {e}")
            return "", [], history
    

        
    def setup_gradio_interface(self):
        with gr.Blocks(css = self.css) as self.retrieval_table:
            with gr.Row():
                self.retrieval_table = gr.Dataframe(interactive=False, wrap=True, line_breaks=True, elem_id="document-table-container", height="800")

        
        with gr.Blocks(css = self.css) as self.chat:
            with gr.Row():
                self.chat_history = gr.Chatbot(label="Chat History", 
                                           layout="panel", 
                                           elem_id="chat-dialogue-container", 
                                           container=True, 
                                           show_copy_button=True,
                                           height="70vh")
            with gr.Row():
                self.input_box = gr.Textbox(label="Type here:", scale=6)
                self.send_button = gr.Button("Send", scale=1)
                self.clear_button = gr.Button("Clear", scale=1)
                
            with gr.Accordion("See Details", open=False):
                self.additional_inputs = [
                    gr.Textbox(label="API Key", value=self.api_key or "Enter your API Key"),
                    gr.Dropdown(self.allowed_models, 
                                value="openai_gpt-3.5-turbo", 
                                label="Model",
                                info="Select openai model"),
                    gr.Slider(label="Top K", value=10, minimum=0, maximum=100, step=5, interactive=True),
                    gr.Slider(label="Temperature", value=1, minimum=0.0, maximum=1.5, step=0.05, interactive=True),
                    gr.Slider(label="Max new tokens", value=256, minimum=256, maximum=4096, step=64, interactive=True),
                    gr.Slider(label="Conversation size", value=12, minimum=2, maximum=36, step=2, interactive=True),
                    gr.Slider(label="Session Cache size", value=12, minimum=2, maximum=36, step=2, interactive=True)
                ]
    
    
            submit_inputs = [self.input_box, self.chat_history]
            submit_inputs.extend(self.additional_inputs)
            # Function to handle sending messages
            self.send_button.click(
                self.chatbot_function, 
                inputs=submit_inputs, 
                outputs=[self.input_box, self.retrieval_table, self.chat_history]
            )
        
            # Function to handle clearing the chat
            self.clear_button.click(
                self.clear_chat, 
                inputs=[], 
                outputs=[self.input_box, self.retrieval_table, self.chat_history]
            )

        
        with gr.Blocks(css = self.css) as self.document_table:
            with gr.Row():
                self.file = gr.File(label="Upload JSON File")
                self.vectorizer = gr.Dropdown(choices=["Doc2Vec", "TFIDF", "MLM"], value="Doc2Vec", label="Select vectorizer")
                self.load_button = gr.Button("load")
            with gr.Row():
                self.data_frame = gr.Dataframe(interactive=True, wrap=True, line_breaks=True, elem_id="document-table-container", height="700")
            with gr.Row():
                self.save_button = gr.Button("save")
                
            self.vectorizer.change(self.change_vectorizer, inputs=[self.vectorizer], outputs=self.data_frame)
            self.load_button.click(self.load_and_filter_json, inputs=[self.file], outputs=self.data_frame)
            self.save_button.click(self.save_df, inputs=[self.data_frame])

        with gr.Blocks(css = self.css, title="Swarmauri Rag Agent", head=head) as self.app:
            gr.TabbedInterface(interface_list=[self.chat, self.retrieval_table, self.document_table], 
                                      tab_names=["chat", "retrieval", "documents"])

    
    def launch(self):
        self.app.launch(share = False,
                        #server_name = "192.168.1.139",
                        favicon_path = "./favicon-32x32.png")

if __name__ == "__main__":
    rag_assistant = RagAssistant(db_path = "E:\\swarmauri_github\\prompt_responses.db")
    rag_assistant.launch()
# Out:
# Initializing... this will take a moment.
# Running on local URL:  http://127.0.0.1:7873
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7873/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
rag_assistant.agent.conversation.history
len(rag_assistant.agent.conversation.history)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 rag_assistant.agent.conversation.history
#       2 len(rag_assistant.agent.conversation.history)
#
# File ~\anaconda3\envs\swarmauri\lib\site-packages\swarmauri\standard\conversations\concrete\SessionCacheConversation.py:64, in SessionCacheConversation.history(self)
#      61 @property
#      62 def history(self) -> List[IMessage]:
#      63     res = []
# ---> 64     res.append(self.system_context)
#      65     res.extend(self._history[-self._max_size:])
#      66     return res
#
# File ~\anaconda3\envs\swarmauri\lib\site-packages\swarmauri\standard\conversations\concrete\SessionCacheConversation.py:82, in SessionCacheConversation.system_context(self)
#      80 """Get the system context message. Raises an error if it's not set."""
#      81 if self._system_context is None:
# ---> 82     raise ValueError("System context has not been set.")
#      83 return self._system_context
#
# ValueError: System context has not been set.

# %%
rag_assistant.agent.conversation.history

# %%
rag_assistant.agent.conversation.as_messages()
# Out:
# [{'content': '', 'role': 'system'}]

# %%
rag_assistant.agent.conversation.as_messages()
# Out:
# [{'content': '```swarmauri/core/__init__.py\n\n```\n```swarmauri/core/models/__init__.py\n\n```\n```swarmauri/core/models/IPredict.py\nfrom abc import ABC, abstractmethod\n\nclass IPredict(ABC):\n    """\n    Interface for making predictions with models.\n    """\n\n    @abstractmethod\n    def predict(self, input_data) -> any:\n        """\n        Generate predictions based on the input data provided to the model.\n        """\n        pass\n```\n```swarmauri/core/models/IFit.py\nfrom abc import ABC, abstractmethod\n\nclass IFit(ABC):\n    """\n    Interface for training models.\n    """\n\n    @abstractmethod\n    def fit(self, X_train, y_train, epochs: int, batch_size: int) -> None:\n        """\n        Train the model on the provided dataset.\n        """\n        pass\n```\n```swarmauri/core/models/IModel.py\nfrom abc import ABC, abstractmethod\n\nclass IModel(ABC):\n    """\n    Interface focusing on the basic properties and settings essential for defining models.\n    """\n\n    @property\n    @abstractmethod\n    def model_name(self) -> str:\n        """\n        Get the name of the model.\n        """\n        pass\n\n    @model_name.setter\n    @abstractmethod\n    def model_name(self, value: str) -> None:\n        """\n        Set the name of the model.\n        """\n        pass\n```',
#   'role': 'system'},
#  {'content': 'hi', 'role': 'user'},
#  {'content': "Hello! It seems like you're working with a Python project using an object-oriented approach, specifically with interfaces for machine learning models.\n\nYou have three interfaces defined:\n\n1. `IPredict`: Models that implement this interface should have a `predict` method, which generates predictions based on input data.\n2. `IFit`: Models that implement this interface should have a `fit` method, which trains the model using the provided dataset.\n3. `IModel`: All models should implement this interface, which defines a `model_name` property.\n\nRemember, the purpose of interfaces is to define a contract that ensures a class implements a specific set of methods. In your case, any class that inherits from these interfaces must implement the methods defined within them.\n\nIf you have any questions about how to use these interfaces, or if you're encountering any issues, feel free to ask! I'm here to help.",
#   'role': 'assistant'}]
