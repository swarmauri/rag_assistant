# %% [markdown]
# ## RagAssistant

# %% [markdown]
# #### Dependendecies

# %%
! pip install swarmauri[full]==0.1.107
# Out:
# Collecting swarmauri==0.1.107 (from swarmauri[full]==0.1.107)
#   Downloading swarmauri-0.1.107-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: numpy in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri==0.1.107->swarmauri[full]==0.1.107) (1.26.4)
# Requirement already satisfied: requests in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri==0.1.107->swarmauri[full]==0.1.107) (2.31.0)
# Requirement already satisfied: openai in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.107) (1.14.1)
# Requirement already satisfied: transformers in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.107) (4.40.1)
# Requirement already satisfied: tensorflow in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.107) (2.11.1)
# Requirement already satisfied: scipy in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.107) (1.10.0)
# Requirement already satisfied: typing-extensions in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.107) (4.10.0)
# Requirement already satisfied: redisearch in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.107) (2.1.1)
# Requirement already satisfied: google-api-python-client in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.107) (2.122.0)
# Requirement already satisfied: google-auth-httplib2 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.107) (0.2.0)
# Requirement already satisfied: google-auth-oauthlib in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.107) (0.4.6)
# Requirement already satisfied: boto3 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.107) (1.34.64)
# Requirement already satisfied: torch in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.107) (2.2.1+cu121)
# Requirement already satisfied: scikit-learn in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.107) (1.4.1.post1)
# Requirement already satisfied: gensim in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.107) (4.3.2)
# Requirement already satisfied: textblob in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.107) (0.18.0.post0)
# Requirement already satisfied: spacy==3.7.4 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.107) (3.7.4)
# Requirement already satisfied: pygments in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.107) (2.17.2)
# Requirement already satisfied: gradio in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.107) (4.26.0)
# Requirement already satisfied: websockets in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.107) (11.0.3)
# Requirement already satisfied: groq in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.107) (0.5.0)
# Requirement already satisfied: mistralai in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.107) (0.1.8)
# Requirement already satisfied: cohere in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.107) (5.3.3)
# Requirement already satisfied: google-generativeai in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.107) (0.5.2)
# Requirement already satisfied: anthropic in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from swarmauri[full]==0.1.107) (0.25.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.107) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.107) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.107) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.107) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.107) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.107) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.107) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.107) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.107) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.107) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.107) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.107) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.107) (4.66.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.107) (2.6.4)
# Requirement already satisfied: jinja2 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.107) (3.1.3)
# Requirement already satisfied: setuptools in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.107) (69.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.107) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from spacy==3.7.4->swarmauri[full]==0.1.107) (3.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from requests->swarmauri==0.1.107->swarmauri[full]==0.1.107) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from requests->swarmauri==0.1.107->swarmauri[full]==0.1.107) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from requests->swarmauri==0.1.107->swarmauri[full]==0.1.107) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from requests->swarmauri==0.1.107->swarmauri[full]==0.1.107) (2024.2.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from anthropic->swarmauri[full]==0.1.107) (4.3.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from anthropic->swarmauri[full]==0.1.107) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from anthropic->swarmauri[full]==0.1.107) (0.25.2)
# Requirement already satisfied: sniffio in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from anthropic->swarmauri[full]==0.1.107) (1.3.1)
# Requirement already satisfied: tokenizers>=0.13.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from anthropic->swarmauri[full]==0.1.107) (0.19.1)
# Requirement already satisfied: botocore<1.35.0,>=1.34.64 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from boto3->swarmauri[full]==0.1.107) (1.34.64)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from boto3->swarmauri[full]==0.1.107) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from boto3->swarmauri[full]==0.1.107) (0.10.1)
# Requirement already satisfied: fastavro<2.0.0,>=1.9.4 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from cohere->swarmauri[full]==0.1.107) (1.9.4)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from cohere->swarmauri[full]==0.1.107) (0.4.0)
# Requirement already satisfied: types-requests<3.0.0,>=2.0.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from cohere->swarmauri[full]==0.1.107) (2.31.0.20240406)
# Requirement already satisfied: httplib2<1.dev0,>=0.15.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from google-api-python-client->swarmauri[full]==0.1.107) (0.22.0)
# Requirement already satisfied: google-auth<3.0.0.dev0,>=1.19.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from google-api-python-client->swarmauri[full]==0.1.107) (2.28.2)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from google-api-python-client->swarmauri[full]==0.1.107) (2.17.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from google-api-python-client->swarmauri[full]==0.1.107) (4.1.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from google-auth-oauthlib->swarmauri[full]==0.1.107) (1.4.0)
# Requirement already satisfied: google-ai-generativelanguage==0.6.2 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from google-generativeai->swarmauri[full]==0.1.107) (0.6.2)
# Requirement already satisfied: protobuf in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from google-generativeai->swarmauri[full]==0.1.107) (3.19.6)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from google-ai-generativelanguage==0.6.2->google-generativeai->swarmauri[full]==0.1.107) (1.23.0)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.107) (23.2.1)
# Requirement already satisfied: altair<6.0,>=4.2.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.107) (5.3.0)
# Requirement already satisfied: fastapi in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.107) (0.110.1)
# Requirement already satisfied: ffmpy in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.107) (0.3.2)
# Requirement already satisfied: gradio-client==0.15.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.107) (0.15.1)
# Requirement already satisfied: huggingface-hub>=0.19.3 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.107) (0.21.4)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.107) (6.4.0)
# Requirement already satisfied: markupsafe~=2.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.107) (2.1.5)
# Requirement already satisfied: matplotlib~=3.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.107) (3.8.3)
# Requirement already satisfied: orjson~=3.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.107) (3.10.0)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.107) (2.2.1)
# Requirement already satisfied: pillow<11.0,>=8.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.107) (10.2.0)
# Requirement already satisfied: pydub in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.107) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.107) (0.0.9)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.107) (6.0.1)
# Requirement already satisfied: ruff>=0.2.2 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.107) (0.3.7)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.107) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.107) (0.12.0)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio->swarmauri[full]==0.1.107) (0.29.0)
# Requirement already satisfied: fsspec in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from gradio-client==0.15.1->gradio->swarmauri[full]==0.1.107) (2024.3.0)
# Requirement already satisfied: hiredis<3.0.0,>=2.0.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from redisearch->swarmauri[full]==0.1.107) (2.3.2)
# Requirement already satisfied: redis==3.5.3 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from redisearch->swarmauri[full]==0.1.107) (3.5.3)
# Requirement already satisfied: rejson<0.6.0,>=0.5.4 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from redisearch->swarmauri[full]==0.1.107) (0.5.6)
# Requirement already satisfied: six<2.0.0,>=1.16.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from redisearch->swarmauri[full]==0.1.107) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from scikit-learn->swarmauri[full]==0.1.107) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from scikit-learn->swarmauri[full]==0.1.107) (3.3.0)
# Requirement already satisfied: tensorflow-intel==2.11.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorflow->swarmauri[full]==0.1.107) (2.11.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.107) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.107) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.107) (24.3.7)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.107) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.107) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.107) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.107) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.107) (3.3.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.107) (2.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.107) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.107) (1.62.1)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.107) (2.11.2)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.107) (2.11.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.107) (2.11.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.107) (0.31.0)
# Requirement already satisfied: nltk>=3.8 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from textblob->swarmauri[full]==0.1.107) (3.8.1)
# Requirement already satisfied: filelock in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from torch->swarmauri[full]==0.1.107) (3.13.1)
# Requirement already satisfied: sympy in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from torch->swarmauri[full]==0.1.107) (1.12)
# Requirement already satisfied: networkx in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from torch->swarmauri[full]==0.1.107) (3.2.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from transformers->swarmauri[full]==0.1.107) (2023.12.25)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from transformers->swarmauri[full]==0.1.107) (0.4.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from altair<6.0,>=4.2.0->gradio->swarmauri[full]==0.1.107) (4.19.2)
# Requirement already satisfied: toolz in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from altair<6.0,>=4.2.0->gradio->swarmauri[full]==0.1.107) (0.12.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from anyio<5,>=3.5.0->anthropic->swarmauri[full]==0.1.107) (1.2.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from botocore<1.35.0,>=1.34.64->boto3->swarmauri[full]==0.1.107) (2.9.0.post0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client->swarmauri[full]==0.1.107) (1.63.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client->swarmauri[full]==0.1.107) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client->swarmauri[full]==0.1.107) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client->swarmauri[full]==0.1.107) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from httplib2<1.dev0,>=0.15.0->google-api-python-client->swarmauri[full]==0.1.107) (3.1.2)
# Requirement already satisfied: httpcore==1.* in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from httpx<1,>=0.23.0->anthropic->swarmauri[full]==0.1.107) (1.0.4)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->anthropic->swarmauri[full]==0.1.107) (0.14.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from matplotlib~=3.0->gradio->swarmauri[full]==0.1.107) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from matplotlib~=3.0->gradio->swarmauri[full]==0.1.107) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from matplotlib~=3.0->gradio->swarmauri[full]==0.1.107) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from matplotlib~=3.0->gradio->swarmauri[full]==0.1.107) (1.4.5)
# Requirement already satisfied: click in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from nltk>=3.8->textblob->swarmauri[full]==0.1.107) (8.1.7)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from pandas<3.0,>=1.0->gradio->swarmauri[full]==0.1.107) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from pandas<3.0,>=1.0->gradio->swarmauri[full]==0.1.107) (2024.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy==3.7.4->swarmauri[full]==0.1.107) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy==3.7.4->swarmauri[full]==0.1.107) (2.16.3)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->swarmauri[full]==0.1.107) (3.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy==3.7.4->swarmauri[full]==0.1.107) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy==3.7.4->swarmauri[full]==0.1.107) (0.1.4)
# Requirement already satisfied: colorama in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy==3.7.4->swarmauri[full]==0.1.107) (0.4.6)
# Requirement already satisfied: shellingham<2.0.0,>=1.3.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from typer[all]<1.0,>=0.9; sys_platform != "emscripten"->gradio->swarmauri[full]==0.1.107) (1.5.4)
# Requirement already satisfied: rich<14.0.0,>=10.11.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from typer[all]<1.0,>=0.9; sys_platform != "emscripten"->gradio->swarmauri[full]==0.1.107) (13.7.1)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy==3.7.4->swarmauri[full]==0.1.107) (0.16.0)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from fastapi->gradio->swarmauri[full]==0.1.107) (0.37.2)
# Requirement already satisfied: mpmath>=0.19 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from sympy->torch->swarmauri[full]==0.1.107) (1.3.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.107) (0.43.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.2->google-generativeai->swarmauri[full]==0.1.107) (1.48.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio->swarmauri[full]==0.1.107) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio->swarmauri[full]==0.1.107) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio->swarmauri[full]==0.1.107) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio->swarmauri[full]==0.1.107) (0.10.6)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client->swarmauri[full]==0.1.107) (0.5.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9; sys_platform != "emscripten"->gradio->swarmauri[full]==0.1.107) (2.2.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.107) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.107) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.107) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.1->tensorflow->swarmauri[full]==0.1.107) (3.0.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\bigman\anaconda3\envs\swarmauri\lib\site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9; sys_platform != "emscripten"->gradio->swarmauri[full]==0.1.107) (0.1.2)
# Downloading swarmauri-0.1.107-py3-none-any.whl (228 kB)
#    ---------------------------------------- 0.0/228.5 kB ? eta -:--:--
#    - -------------------------------------- 10.2/228.5 kB ? eta -:--:--
#    ----- --------------------------------- 30.7/228.5 kB 640.0 kB/s eta 0:00:01
#    ---------- ---------------------------- 61.4/228.5 kB 656.4 kB/s eta 0:00:01
#    ---------------------------------- ----- 194.6/228.5 kB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 228.5/228.5 kB 1.5 MB/s eta 0:00:00
# Installing collected packages: swarmauri
#   Attempting uninstall: swarmauri
#     Found existing installation: swarmauri 0.1.106
#     Uninstalling swarmauri-0.1.106:
#       Successfully uninstalled swarmauri-0.1.106
# Successfully installed swarmauri-0.1.107
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# swarmauri-developer 0.0.8 requires swarmauri[full]==0.1.80, but you have swarmauri 0.1.107 which is incompatible.

# %%
from datetime import datetime
import sqlite3
import gradio as gr
import pandas as pd
import json
from typing import Any, Optional, Union, Dict
from swarmauri.standard.models.concrete.OpenAIModel import OpenAIModel
from swarmauri.standard.models.concrete.GroqModel import GroqModel
from swarmauri.standard.models.concrete.MistralModel import MistralModel
from swarmauri.standard.models.concrete.GeminiProModel import GeminiProModel
from swarmauri.standard.models.concrete.AnthropicModel import AnthropicModel
from swarmauri.standard.vector_stores.concrete.TFIDFVectorStore import TFIDFVectorStore
from swarmauri.standard.vector_stores.concrete.Doc2VecVectorStore import Doc2VecVectorStore
from swarmauri.standard.vector_stores.concrete.MLMVectorStore import MLMVectorStore
from swarmauri.standard.conversations.concrete.SessionCacheConversation import SessionCacheConversation
from swarmauri.standard.agents.concrete.RagAgent import RagAgent
from swarmauri.core.messages import IMessage
from swarmauri.core.models.IModel import IModel
from swarmauri.standard.conversations.base.SystemContextBase import SystemContextBase
from swarmauri.standard.agents.base.VectorStoreAgentBase import VectorStoreAgentBase
from swarmauri.standard.vector_stores.base.VectorDocumentStoreRetrieveBase import VectorDocumentStoreRetrieveBase
from swarmauri.standard.documents.concrete.Document import Document
from swarmauri.standard.documents.concrete.EmbeddedDocument import EmbeddedDocument
from swarmauri.standard.messages.concrete import (HumanMessage, 
                                                  SystemMessage,
                                                  AgentMessage)
from swarmauri.standard.utils.load_documents_from_json import load_documents_from_json_file
# Out:
# C:\Users\bigman\anaconda3\envs\swarmauri\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated and will be removed in a future release
#   "class": algorithms.Blowfish,

# %% [raw]
# import json
# from typing import List
# import google.generativeai as genai
# from swarmauri.core.models.IPredict import IPredict
# from swarmauri.standard.models.base.ModelBase import ModelBase
#
#
# class GeminiProModel(ModelBase, IPredict):
#     allowed_models = ['gemini-1.5-pro-latest']
#
#     def __init__(self, api_key: str, model_name: str = 'gemini-1.5-pro-latest'):
#         if model_name not in self.allowed_models:
#             raise ValueError(f"Model name '{model_name}' is not supported. Choose from {self.allowed_models}")
#
#         genai.configure(api_key=api_key)
#         self.safety_settings = [
#           {
#             "category": "HARM_CATEGORY_HARASSMENT",
#             "threshold": "BLOCK_MEDIUM_AND_ABOVE"
#           },
#           {
#             "category": "HARM_CATEGORY_HATE_SPEECH",
#             "threshold": "BLOCK_MEDIUM_AND_ABOVE"
#           },
#           {
#             "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
#             "threshold": "BLOCK_MEDIUM_AND_ABOVE"
#           },
#           {
#             "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
#             "threshold": "BLOCK_MEDIUM_AND_ABOVE"
#           },
#         ]
#         self.safety_settings = [
#           {
#             "category": "HARM_CATEGORY_HARASSMENT",
#             "threshold": "BLOCK_MEDIUM_AND_ABOVE"
#           },
#           {
#             "category": "HARM_CATEGORY_HATE_SPEECH",
#             "threshold": "BLOCK_MEDIUM_AND_ABOVE"
#           },
#           {
#             "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
#             "threshold": "BLOCK_MEDIUM_AND_ABOVE"
#           },
#           {
#             "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
#             "threshold": "BLOCK_MEDIUM_AND_ABOVE"
#           },
#         ]
#         self.client = None
#         super().__init__(model_name)
#
#
#     def predict(self, messages, temperature=0.7, max_tokens=256):
#         generation_config = {
#             "temperature": temperature,
#             "top_p": 0.95,
#             "top_k": 0,
#             "max_output_tokens": max_tokens,
#             }
#
#         system_context = None
#         for message in messages:
#
#             # update role naming
#             role = message.pop('role')
#             if role == 'assistant':
#                 role = 'model'
#
#             if role == 'system':
#                 system_context = message['content']
#
#             # rename role
#             message['role'] = role
#
#             # update content naming
#             message['parts'] = message.pop('content')
#
#
#         # Remove system instruction from messages
#         sanitized_messages = [message for message in messages if message['role'] != 'system']
#
#         # if we remove more than one system message from the array
#         # then we know we were given too many system messages
#         # we raise an error in this scenario.
#         # Examples:
#         # 10 - 1 = 9 so if 9 + 1 < 10  then negative is good
#         # 10 - 2 = 8, so if 8 + 1 < 10 then positive is bad
#         if len(sanitized_messages) + 1 > len(messages):
#             raise ValueError('cannot send an array of conversations containing more than one system instruction.')
#
#
#         next_message = sanitized_messages.pop()
#
#         self.client = genai.GenerativeModel(model_name=self.model_name,
#             safety_settings=self.safety_settings,
#             generation_config=generation_config)
#
#         convo = self.client.start_chat(
#             history=sanitized_messages,
#             )
#
#         convo.send_message(next_message['parts'])
#
#         message_content = convo.last.text
#
#         return message_content

# %% [raw]
# import json
# from typing import List
# import anthropic
# from swarmauri.core.models.IPredict import IPredict
# from swarmauri.standard.models.base.ModelBase import ModelBase
#
#
# class AnthropicModel(ModelBase, IPredict):
#     allowed_models = ['claude-3-opus-20240229', 'claude-3-sonnet-20240229', 'claude-3-haiku-20240307']
#
#     def __init__(self, api_key: str, model_name: str = 'claude-3-haiku-20240307'):
#         if model_name not in self.allowed_models:
#             raise ValueError(f"Model name '{model_name}' is not supported. Choose from {self.allowed_models}")
#
#         self.client = anthropic.Anthropic(api_key=api_key)
#         super().__init__(model_name)
#
#
#     def predict(self, messages, temperature=0.7, max_tokens=256):
#
#
#
#         # Get system_context
#         system_context = None
#         for message in messages:
#             if message['role'] == 'system':
#                 print(message)
#                 system_context = message['content']
#                 print(message)
#
#         # Remove system instruction from messages
#         sanitized_messages = [message for message in messages if message['role'] != 'system']
#
#         # we should only remove one message for system instruction
#         if len(sanitized_messages) + 1 > len(messages):
#             raise ValueError('cannot send an array of conversations containing more than one system instruction.')
#
#         # Chat
#         response = self.client.messages.create(
#             model=self.model_name,
#             messages=sanitized_messages,
#             system=system_context,
#             temperature=temperature,
#             max_tokens=max_tokens
#         )
#         print('response', )
#         print('response.content', response.content)
#         print('response.content', response.content[0].text)
#
#
#         message_content = response.content[0].text
#         return message_content

# %% [markdown]
# #### Project Class

# %%
head="""<link rel="icon" href="data:image/png;base64,..." type="image/png">"""

# %%
class RagAssistant:
    def __init__(self, api_key: str = "", db_path='prompt_responses.db', 
                 vector_store_path=None, model_name = "openai_gpt-4-0125-preview"):
        print('Initializing... this will take a moment.')
        self.api_key = api_key
        self.db_path = db_path
        self.conversation = SessionCacheConversation(max_size=2, system_message_content="")
        self.allowed_models =sorted(['groq_llama3-8b-8192',
                            'groq_llama3-70b-8192',
                            'groq_mixtral-8x7b-32768',
                            'groq_gemma-7b-it',
                            'mistral_mistral-medium-latest',
                            'mistral_mistral-small-latest',
                            'mistral_open-mixtral-8x22b',
                            'mistral_open-mixtral-8x7b',
                            'mistral_open-mistral-7b',
                            'mistral_mistral-large-latest',
                            'openai_gpt-3.5-turbo',
                            'openai_gpt-3.5-turbo-16k',
                            'openai_gpt-4-0125-preview',
                            'google_gemini-1.5-pro-latest',
                            'anthropic_claude-2.0',
                            'anthropic_claude-instant-1.2',
                            'anthropic_claude-2.1',
                            'anthropic_claude-3-opus-20240229',
                            'anthropic_claude-3-sonnet-20240229',
                            'anthropic_claude-3-haiku-20240307'])
            
        self.model = None
        self.retrieval_table = []
        self.document_table = []
        self.long_term_memory_df = None
        self.last_recall_df = None
        self.agent = self.initialize_agent()
        self.set_model(model_name)
        self.css = """
#chat-dialogue-container {
    min-height: 54vh !important;
}

#document-table-container {
    min-height: 80vh !important;
}

footer {
    display: none !important;
}
"""
        self.setup_gradio_interface()
        
    def initialize_agent(self):
        VS = Doc2VecVectorStore()
        agent = RagAgent(name="Rag", model=self.model, conversation=self.conversation, vector_store=VS)
        return agent

    def set_model(self, provider_model_choice: str):
        if provider_model_choice in self.allowed_models:
            provider, model_name = provider_model_choice.split('_')
            if provider == 'groq':
                self.model = GroqModel(api_key=self.api_key, model_name=model_name)
                
            if provider == 'mistral':
                self.model = MistralModel(api_key=self.api_key, model_name=model_name)
                
            if provider == 'openai':
                self.model = OpenAIModel(api_key=self.api_key, model_name=model_name)

            if provider == 'google':
                self.model = GeminiProModel(api_key=self.api_key, model_name=model_name)

            if provider == 'anthropic':
                self.model = AnthropicModel(api_key=self.api_key, model_name=model_name)
            
            self.agent.model = self.model
                
        else:
            raise ValueError(f"Model name '{model_name}' is not supported. Choose from {self.allowed_models}")

    def change_vectorizer(self, vectorizer: str):
        if vectorizer == 'Doc2Vec':
            self.agent.vector_store = Doc2VecVectorStore()
        if vectorizer == 'MLM':
            self.agent.vector_store = MLMVectorStore()
        else:
            self.agent.vector_store = TFIDFVectorStore()
            
    
    def load_and_filter_json(self, file_info):
        # Load JSON file using json library
        try:
            documents = load_documents_from_json_file(file_info.name)
            self.agent.vector_store.documents = []
            self.agent.vector_store.add_documents(documents)
            self.long_term_memory_df = self.preprocess_documents(documents)
            return self.long_term_memory_df
        except json.JSONDecodeError:
            return "Invalid JSON file. Please check the file and try again."

    def preprocess_documents(self, documents):
        try:
            docs = [d.to_dict() for d in documents]
            for d in docs:
                metadata = d['metadata']
                for each in metadata:
                    d[each] = metadata[each]
                del d['metadata']
                del d['type']
                del d['embedding']
            df = pd.DataFrame.from_dict(docs)
            return df
        except Exception as e:
            print(f"postprocess_documents: {e}")

    
    def sql_log(self, conversation_id, model_name, prompt, response, start_datetime, end_datetime):
        try:
            duration = (end_datetime - start_datetime).total_seconds()
            start_datetime = start_datetime.isoformat()
            end_datetime = end_datetime.isoformat()
            conversation_id = str(conversation_id)
            conn = sqlite3.connect(self.db_path)
            cursor = conn.cursor()
            cursor.execute('''CREATE TABLE IF NOT EXISTS conversations
                            (id INTEGER PRIMARY KEY AUTOINCREMENT, 
                            conversation_id TEXT, 
                            model_name TEXT, 
                            prompt TEXT, 
                            response TEXT, 
                            start_datetime TEXT, 
                            end_datetime TEXT,
                            duration NUMERIC)''')
            cursor.execute('''INSERT INTO conversations (
                            conversation_id, 
                            model_name, 
                            prompt, 
                            response, 
                            start_datetime, 
                            end_datetime,
                            duration) VALUES (?, ?, ?, ?, ?, ?, ?)''', 
                           (conversation_id, 
                            model_name, 
                            prompt, 
                            response, 
                            start_datetime, 
                            end_datetime, 
                            duration))
            conn.commit()
            conn.close()
        except:
            raise
    
    def save_df(self, df):
        documents = self.dataframe_to_documents(df)
        self.agent.vector_store.documents = []
        self.agent.vector_store.add_documents(documents)
        self.long_term_memory_df = self.preprocess_documents(documents)
        return self.long_term_memory_df

    def dataframe_to_documents(self, df):
        documents = []
        for index, row in df.iterrows():
            row_dict = row.to_dict() 
            id = row_dict.pop("id", "")
            content = row_dict.pop("content", "")
            metadata = row_dict  # remaining data becomes metadata
        
            # Convert the row to dictionary and create a DocumentBase instance
            
            document = EmbeddedDocument(id=id, content=content, metadata=metadata)
            documents.append(document)
        return documents
        
    def clear_chat(self):
        # We could clear, but if we create a new instance, we get a new conversation id
        max_size = self.agent.conversation.max_size
        session_cache_size = self.agent.conversation.session_cache_max_size
        self.conversation = SessionCacheConversation(max_size=max_size, 
                                                     system_message_content="", 
                                                     session_cache_max_size=session_cache_size)
        self.agent.conversation = self.conversation
        return "", [], []    
        
    async def chatbot_function(self, 
                         message, 
                         history, 
                         api_key: str = None, 
                         model_name: str = None, 
                         top_k: int = 5, 
                         temperature: int = 1, 
                         max_tokens: int = 256,
                         conversation_size: int = 2,
                         session_cache_size: int = 2):
        try:
            start_datetime = datetime.now()
            if self.agent.vector_store.document_count() == 0:
                return "", [], [(message, "⚠️ Add Documents First")]
            else:

                
                
                # Set additional parameters
                self.api_key = api_key
                self.set_model(model_name)
                #print(self.model, self.model.model_name, self.api_key)

                # Set Conversation Size
                self.agent.conversation.max_size = conversation_size
                self.agent.conversation.session_cache_max_size = session_cache_size
                
                # Predict
                response = self.agent.exec(message, top_k=top_k, model_kwargs={'temperature': temperature, 'max_tokens': max_tokens})
    
                # Update Retrieval Document Table
                self.last_recall_df = self.preprocess_documents(self.agent.last_similar_documents)
                
                # Get History
                history = [each['content'] for each in self.agent.conversation.session_to_dict()]
                history = [(history[i], history[i+1]) for i in range(0, len(history), 2)]

                # SQL Log
                end_datetime = datetime.now()
                self.sql_log(self.agent.conversation.id, model_name, message, response, start_datetime, end_datetime)
                
                return "", self.last_recall_df, history
        except Exception as e:
            gr.Error(f"{e}")
            self.agent.conversation._history.pop(0)
            print(f"chatbot_function error: {e}")
            return "", [], history
    

        
    def setup_gradio_interface(self):
        with gr.Blocks(css = self.css) as self.retrieval_table:
            with gr.Row():
                self.retrieval_table = gr.Dataframe(interactive=False, wrap=True, line_breaks=True, elem_id="document-table-container", height="800")

        
        with gr.Blocks(css = self.css) as self.chat:
            with gr.Row():
                self.chat_history = gr.Chatbot(label="Chat History", 
                                           layout="panel", 
                                           elem_id="chat-dialogue-container", 
                                           container=True, 
                                           show_copy_button=True,
                                           height="70vh")
            with gr.Row():
                self.input_box = gr.Textbox(label="Type here:", scale=6)
                self.send_button = gr.Button("Send", scale=1)
                self.clear_button = gr.Button("Clear", scale=1)
                
            with gr.Accordion("See Details", open=False):
                self.additional_inputs = [
                    gr.Textbox(label="API Key", value=self.api_key or "Enter your API Key"),
                    gr.Dropdown(self.allowed_models, 
                                value="openai_gpt-3.5-turbo", 
                                label="Model",
                                info="Select openai model"),
                    gr.Slider(label="Top K", value=10, minimum=0, maximum=100, step=5, interactive=True),
                    gr.Slider(label="Temperature", value=1, minimum=0.0, maximum=1, step=0.01, interactive=True),
                    gr.Slider(label="Max new tokens", value=256, minimum=256, maximum=4096, step=64, interactive=True),
                    gr.Slider(label="Conversation size", value=12, minimum=2, maximum=36, step=2, interactive=True),
                    gr.Slider(label="Session Cache size", value=12, minimum=2, maximum=36, step=2, interactive=True)
                ]
    
    
            submit_inputs = [self.input_box, self.chat_history]
            submit_inputs.extend(self.additional_inputs)
            # Function to handle sending messages
            self.send_button.click(
                self.chatbot_function, 
                inputs=submit_inputs, 
                outputs=[self.input_box, self.retrieval_table, self.chat_history]
            )
        
            # Function to handle clearing the chat
            self.clear_button.click(
                self.clear_chat, 
                inputs=[], 
                outputs=[self.input_box, self.retrieval_table, self.chat_history]
            )

        
        with gr.Blocks(css = self.css) as self.document_table:
            with gr.Row():
                self.file = gr.File(label="Upload JSON File")
                self.vectorizer = gr.Dropdown(choices=["Doc2Vec", "TFIDF", "MLM"], value="Doc2Vec", label="Select vectorizer")
                self.load_button = gr.Button("load")
            with gr.Row():
                self.data_frame = gr.Dataframe(interactive=True, wrap=True, line_breaks=True, elem_id="document-table-container", height="700")
            with gr.Row():
                self.save_button = gr.Button("save")
                
            self.vectorizer.change(self.change_vectorizer, inputs=[self.vectorizer], outputs=self.data_frame)
            self.load_button.click(self.load_and_filter_json, inputs=[self.file], outputs=self.data_frame)
            self.save_button.click(self.save_df, inputs=[self.data_frame])

        with gr.Blocks(css = self.css, title="Swarmauri Rag Agent", head=head) as self.app:
            gr.TabbedInterface(interface_list=[self.chat, self.retrieval_table, self.document_table], 
                                      tab_names=["chat", "retrieval", "documents"])

    
    def launch(self):
        self.app.launch(share = False,
                        #server_name = "192.168.1.139",
                        favicon_path = "./favicon-32x32.png")

if __name__ == "__main__":
    rag_assistant = RagAssistant(db_path = "E:\\swarmauri_github\\prompt_responses.db")
    rag_assistant.launch()
# Out:
# Initializing... this will take a moment.
# Running on local URL:  http://127.0.0.1:7864
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7864/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Traceback (most recent call last):
#   File "C:\Users\bigman\anaconda3\envs\swarmauri\lib\site-packages\gradio\queueing.py", line 527, in process_events
#     response = await route_utils.call_process_api(
#   File "C:\Users\bigman\anaconda3\envs\swarmauri\lib\site-packages\gradio\route_utils.py", line 261, in call_process_api
#     output = await app.get_blocks().process_api(
#   File "C:\Users\bigman\anaconda3\envs\swarmauri\lib\site-packages\gradio\blocks.py", line 1786, in process_api
#     result = await self.call_function(
#   File "C:\Users\bigman\anaconda3\envs\swarmauri\lib\site-packages\gradio\blocks.py", line 1338, in call_function
#     prediction = await anyio.to_thread.run_sync(
#   File "C:\Users\bigman\anaconda3\envs\swarmauri\lib\site-packages\anyio\to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#   File "C:\Users\bigman\anaconda3\envs\swarmauri\lib\site-packages\anyio\_backends\_asyncio.py", line 2144, in run_sync_in_worker_thread
#     return await future
#   File "C:\Users\bigman\anaconda3\envs\swarmauri\lib\site-packages\anyio\_backends\_asyncio.py", line 851, in run
#     result = context.run(func, *args)
#   File "C:\Users\bigman\anaconda3\envs\swarmauri\lib\site-packages\gradio\utils.py", line 759, in wrapper
#     response = f(*args, **kwargs)
#   File "C:\Users\bigman\AppData\Local\Temp\ipykernel_32356\2420356959.py", line 93, in load_and_filter_json
#     self.agent.vector_store.add_documents(documents)
#   File "C:\Users\bigman\anaconda3\envs\swarmauri\lib\site-packages\swarmauri\standard\vector_stores\concrete\Doc2VecVectorStore.py", line 23, in add_documents
#     self._recalculate_embeddings()
#   File "C:\Users\bigman\anaconda3\envs\swarmauri\lib\site-packages\swarmauri\standard\vector_stores\concrete\Doc2VecVectorStore.py", line 48, in _recalculate_embeddings
#     embeddings = self.vectorizer.fit_transform(documents_text)
#   File "C:\Users\bigman\anaconda3\envs\swarmauri\lib\site-packages\swarmauri\standard\vectorizers\concrete\Doc2VecVectorizer.py", line 31, in fit_transform
#     self.fit(documents, **kwargs)
#   File "C:\Users\bigman\anaconda3\envs\swarmauri\lib\site-packages\swarmauri\standard\vectorizers\concrete\Doc2VecVectorizer.py", line 20, in fit
#     self.model.build_vocab(tagged_data)
#   File "C:\Users\bigman\anaconda3\envs\swarmauri\lib\site-packages\gensim\models\doc2vec.py", line 888, in build_vocab
#     report_values = self.prepare_vocab(update=update, keep_raw_vocab=keep_raw_vocab, trim_rule=trim_rule, **kwargs)
#   File "C:\Users\bigman\anaconda3\envs\swarmauri\lib\site-packages\gensim\models\word2vec.py", line 769, in prepare_vocab
#     self.wv.sort_by_descending_frequency()
#   File "C:\Users\bigman\anaconda3\envs\swarmauri\lib\site-packages\gensim\models\keyedvectors.py", line 757, in sort_by_descending_frequency
#     self.vectors = self.vectors[count_sorted_indexes]
# IndexError: index 1302 is out of bounds for axis 0 with size 795
# Traceback (most recent call last):
#   File "C:\Users\bigman\anaconda3\envs\swarmauri\lib\site-packages\gradio\queueing.py", line 527, in process_events
#     response = await route_utils.call_process_api(
#   File "C:\Users\bigman\anaconda3\envs\swarmauri\lib\site-packages\gradio\route_utils.py", line 261, in call_process_api
#     output = await app.get_blocks().process_api(
#   File "C:\Users\bigman\anaconda3\envs\swarmauri\lib\site-packages\gradio\blocks.py", line 1786, in process_api
#     result = await self.call_function(
#   File "C:\Users\bigman\anaconda3\envs\swarmauri\lib\site-packages\gradio\blocks.py", line 1338, in call_function
#     prediction = await anyio.to_thread.run_sync(
#   File "C:\Users\bigman\anaconda3\envs\swarmauri\lib\site-packages\anyio\to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#   File "C:\Users\bigman\anaconda3\envs\swarmauri\lib\site-packages\anyio\_backends\_asyncio.py", line 2144, in run_sync_in_worker_thread
#     return await future
#   File "C:\Users\bigman\anaconda3\envs\swarmauri\lib\site-packages\anyio\_backends\_asyncio.py", line 851, in run
#     result = context.run(func, *args)
#   File "C:\Users\bigman\anaconda3\envs\swarmauri\lib\site-packages\gradio\utils.py", line 759, in wrapper
#     response = f(*args, **kwargs)
#   File "C:\Users\bigman\AppData\Local\Temp\ipykernel_32356\2420356959.py", line 93, in load_and_filter_json
#     self.agent.vector_store.add_documents(documents)
#   File "C:\Users\bigman\anaconda3\envs\swarmauri\lib\site-packages\swarmauri\standard\vector_stores\concrete\Doc2VecVectorStore.py", line 23, in add_documents
#     self._recalculate_embeddings()
#   File "C:\Users\bigman\anaconda3\envs\swarmauri\lib\site-packages\swarmauri\standard\vector_stores\concrete\Doc2VecVectorStore.py", line 48, in _recalculate_embeddings
#     embeddings = self.vectorizer.fit_transform(documents_text)
#   File "C:\Users\bigman\anaconda3\envs\swarmauri\lib\site-packages\swarmauri\standard\vectorizers\concrete\Doc2VecVectorizer.py", line 31, in fit_transform
#     self.fit(documents, **kwargs)
#   File "C:\Users\bigman\anaconda3\envs\swarmauri\lib\site-packages\swarmauri\standard\vectorizers\concrete\Doc2VecVectorizer.py", line 20, in fit
#     self.model.build_vocab(tagged_data)
#   File "C:\Users\bigman\anaconda3\envs\swarmauri\lib\site-packages\gensim\models\doc2vec.py", line 888, in build_vocab
#     report_values = self.prepare_vocab(update=update, keep_raw_vocab=keep_raw_vocab, trim_rule=trim_rule, **kwargs)
#   File "C:\Users\bigman\anaconda3\envs\swarmauri\lib\site-packages\gensim\models\word2vec.py", line 769, in prepare_vocab
#     self.wv.sort_by_descending_frequency()
#   File "C:\Users\bigman\anaconda3\envs\swarmauri\lib\site-packages\gensim\models\keyedvectors.py", line 757, in sort_by_descending_frequency
#     self.vectors = self.vectors[count_sorted_indexes]
# IndexError: index 1302 is out of bounds for axis 0 with size 795
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Epoch 1 complete. Loss 0.3482102155685425

# %%
rag_assistant.agent.conversation.history
len(rag_assistant.agent.conversation.history)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 rag_assistant.agent.conversation.history
#       2 len(rag_assistant.agent.conversation.history)
#
# File ~\anaconda3\envs\swarmauri\lib\site-packages\swarmauri\standard\conversations\concrete\SessionCacheConversation.py:64, in SessionCacheConversation.history(self)
#      61 @property
#      62 def history(self) -> List[IMessage]:
#      63     res = []
# ---> 64     res.append(self.system_context)
#      65     res.extend(self._history[-self._max_size:])
#      66     return res
#
# File ~\anaconda3\envs\swarmauri\lib\site-packages\swarmauri\standard\conversations\concrete\SessionCacheConversation.py:82, in SessionCacheConversation.system_context(self)
#      80 """Get the system context message. Raises an error if it's not set."""
#      81 if self._system_context is None:
# ---> 82     raise ValueError("System context has not been set.")
#      83 return self._system_context
#
# ValueError: System context has not been set.

# %%
rag_assistant.agent.conversation.history

# %%
rag_assistant.agent.conversation.as_messages()
# Out:
# [{'content': '```swarmauri/core/parsers/IParser.py\nfrom abc import ABC, abstractmethod\nfrom typing import List, Union, Any\nfrom ..documents.IDocument import IDocument\n\nclass IParser(ABC):\n    """\n    Abstract base class for parsers. It defines a public method to parse input data (str or Message) into documents,\n    and relies on subclasses to implement the specific parsing logic through protected and private methods.\n    """\n\n    @abstractmethod\n    def parse(self, data: Union[str, Any]) -> List[IDocument]:\n        """\n        Public method to parse input data (either a str or a Message) into a list of Document instances.\n        \n        This method leverages the abstract _parse_data method which must be\n        implemented by subclasses to define specific parsing logic.\n        """\n        pass\n\n\n```\n```swarmauri/core/chains/IChainStep.py\nfrom typing import List, Dict, Any, Callable\n\nclass IChainStep:\n    """\n    Represents a single step within an execution chain.\n    """\n    def __init__(self, \n        key: str, \n        method: Callable, \n        args: List[Any] = None, \n        kwargs: Dict[str, Any] = None, \n        ref: str = None):\n        """\n        Initialize a chain step.\n\n        Args:\n            key (str): Unique key or identifier for the step.\n            method (Callable): The callable object (function or method) to execute in this step.\n            args (List[Any], optional): Positional arguments for the callable.\n            kwargs (Dict[str, Any], optional): Keyword arguments for the callable.\n            ref (str, optional): Reference to another component or context variable, if applicable.\n        """\n        self.key = key\n        self.method = method\n        self.args = args if args is not None else []\n        self.kwargs = kwargs if kwargs is not None else {}\n        self.ref = ref\n```\n```swarmauri/core/tracing/IChainTracer.py\nfrom abc import ABC, abstractmethod\nfrom typing import Callable, List, Tuple, Dict, Any\n\nclass IChainTracer(ABC):\n    """\n    Interface for a tracer supporting method chaining through a list of tuples.\n    Each tuple in the list contains: trace context, function, args, and kwargs.\n    """\n\n    @abstractmethod\n    def process_chain(self, chain: List[Tuple[Any, Callable[..., Any], List[Any], Dict[str, Any]]]) -> "IChainTracer":\n        """\n        Processes a sequence of operations defined in a chain.\n\n        Args:\n            chain (List[Tuple[Any, Callable[..., Any], List[Any], Dict[str, Any]]]): A list where each tuple contains:\n                - The trace context or reference required by the function.\n                - The function (method of IChainTracer) to execute.\n                - A list of positional arguments for the function.\n                - A dictionary of keyword arguments for the function.\n\n        Returns:\n            IChainTracer: Returns self to allow further method chaining.\n        """\n        pass\n```\n```swarmauri/core/metrics/ICalculateMetric.py\nfrom typing import Any\nfrom abc import ABC, abstractmethod\n\nclass ICalculateMetric(ABC):\n\n    @abstractmethod\n    def calculate(self, **kwargs) -> Any:\n        """\n        Calculate the metric based on the provided data.\n\n        Args:\n            *args: Variable length argument list that the metric calculation might require.\n            **kwargs: Arbitrary keyword arguments that the metric calculation might require.\n        """\n        pass\n\n    @abstractmethod\n    def update(self, value) -> None:\n        """\n        Update the metric value based on new information.\n\n        Args:\n            value: The new information used to update the metric. This could be a new\n            measurement or data point that affects the metric\'s current value.\n\n        Note:\n            This method is intended for internal use and should not be publicly accessible.\n        """\n        pass\n\n\n```\n```swarmauri/standard/chai ...
#   'role': 'system'},
#  {'content': 'explain swarmauri/standard/chains/concrete/ChainStep',
#   'role': 'user'},
#  {'content': "The `ChainStep` in the `swarmauri/standard/chains/concrete` directory is conceptualized as a part of a broader system designed to execute specific tasks or functions within an execution chain. The name `ChainStep` implies that it represents a single step or action that can be executed as part of a sequence of operations in the context of a process or workflow. In a more detailed explanation, here is how the `ChainStep` is structured and intended to be utilized within the system:\n\n### Purpose\n\nThe primary purpose of `ChainStep` is to modularize and encapsulate individual operations or function calls within an execution chain. This modularization allows for better abstraction, manageability, and reuse of functionality within complex systems. Each `ChainStep` is designed to perform a specific task, which could range from calling a computational function, making a database query, sending a request to an external service, or any other discrete action required by the application logic.\n\n### Structure\n\nA `ChainStep` typically contains the following key components or attributes:\n\n- **Key (Identifier):** A unique identifier or name for the step. This helps in referencing and managing the step within the chain.\n- **Method (Callable):** The actual method or function that the step will execute. This could be any callable object that performs the desired operation.\n- **Arguments (Args):** Positional arguments that need to be passed to the method when it is called.\n- **Keyword Arguments (Kwargs):** Keyword or named arguments that need to be passed to the method.\n- **Reference (Ref):** Optionally, a step can have a reference to where its result should be stored or how it interacts with the chain's state. This could be used for accessing the output of the step or linking steps together.\n\n### Operation\n\n- **Execution:** When a chain containing `ChainStep` instances is executed, each step in the sequence is processed in order. The chain's execution mechanism handles invoking the step’s method with the provided arguments and managing any state or data flow between steps.\n- **Data Flow and Context:** Steps can optionally produce output or affect the state of the execution context. This can enable data flow and dependencies between steps in a chain, where the output of one step could be used as input for another.\n\n### Use Cases\n\nImplementing execution logic as a series of `ChainStep` instances provides several advantages:\n\n- **Flexibility and Reusability:** Each step can be designed as a reusable component. This allows for constructing various chains from a common pool of steps to address different scenarios or workflows.\n- **Decoupling:** Steps are decoupled from each other, promoting a separation of concerns. The chain's structure defines the sequence and data dependencies, not the steps themselves.\n- **Maintainability:** Managing and updating the logic becomes more straightforward. Changes in one step are isolated and less likely to impact others, assuming the interfaces remain consistent.\n- **Debugging and Analysis:** The execution can be inspected, logged, or analyzed step by step, making it easier to debug and understand the flow of operations.\n\nIn practical terms, the `ChainStep` class would be implemented in Python, potentially with a method to execute the step and mechanisms to interact with the overall execution environment or context of the chain. It acts as a building block for constructing dynamic and flexible execution flows within a software system, contributing to a design that is both modular and adaptable.\n\nNote: The concrete implementation details like file paths or method names might differ in the actual codebase, and some features might be simplified or generalized for explanation purposes.",
#   'role': 'assistant'},
#  {'content': 'explain StateChain', 'role': 'user'},
#  {'content': "A `StateChain` represents an advanced, structured approach to managing a sequence of operations or tasks where the state (context) plays a crucial role in directing the flow and outcomes of the execution. It is essentially an evolution or extension of the basic chain concept, with an emphasis on state management across different steps in the chain. Here's a breakdown of what a `StateChain` entails, its components, and how it functions:\n\n### Purpose\n\nThe purpose of a `StateChain` is to enable complex, stateful workflows where the output or result of one step can influence or determine the operations of subsequent steps. This is particularly useful in scenarios where decisions and operations need to be dynamically adjusted based on intermediate results or external inputs.\n\n### Components\n\nA `StateChain` typically comprises:\n\n- **Steps:** These are individual operations or tasks, represented by `ChainStep` instances or similar constructs, that the chain will execute in a predefined order.\n- **State/Context:** A shared data structure or context that stores intermediate results, variables, and other information that might be needed across different steps in the chain. This state is accessible to all steps, allowing for dynamic decision-making and flow control based on the current state.\n- **Execution Logic:** The mechanism by which the chain decides the order of step execution, possibly including conditional branching, loops, or other control structures, based on the current state.\n\n### Operation\n\n- **Initialization:** When a `StateChain` is instantiated, it initializes with an empty or predefined state/context.\n- **Execution Flow:** As the chain executes, each step reads from and optionally writes to the shared state/context, allowing for information to be passed along the chain. The specific path of execution might change dynamically, depending on the state updates throughout the process.\n- **State Modification:** Steps can modify the state by adding new data, updating existing data, or even removing data. This capability is central to achieving dynamic and adaptable execution flows.\n\n### Use Cases\n\n`StateChain` is particularly useful in scenarios where the execution logic needs to adapt based on runtime data or where steps in a process are interdependent. Use cases include:\n\n- **Workflow Management:** In complex workflows, where the next steps depend on outcomes or metrics calculated in previous steps.\n- **Data Pipelines:** For managing pipelines where subsequent operations depend on the artifacts or results produced by earlier operations.\n- **Decision Trees:** Implementing decision trees where each node represents a decision-making point influenced by the current state or context.\n- **Game Development:** Managing game states and transitions between different states of the game.\n\n### Benefits\n\n- **Flexibility:** A `StateChain` offers the flexibility to adapt the execution flow based on runtime data and outcomes from preceding steps.\n- **Modularity:** It promotes modularity by decoupling the execution steps from the control logic, allowing steps to focus on their specific tasks.\n- **Maintainability:** The structured approach to state management simplifies tracking dependencies and interactions across steps, which facilitates debugging, maintenance, and updates.\n- **Reusability:** Steps designed for `StateChains` can be reused in different chains, maximizing code reuse and reducing redundancy.\n\nIn summary, a `StateChain` offers a powerful and flexible framework for designing and executing complex, stateful sequences of operations. Its emphasis on state management enables dynamic control over the execution flow, making it well-suited for a wide range of applications that require adaptive logic based on runtime conditions and intermediate outcomes.",
#   'role': 'assistant'},
#  {'content': 'explain how swarmauri/standard/chains/concrete/StateChain and swarmauri/standard/chains/concret/ChainStep can be leveraged together. show code',
#   'role': 'user'},
#  {'content': 'To effectively leverage `StateChain` and `ChainStep` together, consider `StateChain` as the orchestration layer that manages the execution of a sequence of `ChainStep`s, where each `ChainStep` represents an individual operation or task that contributes to the overall goal of the `StateChain`. The core idea is to use the `StateChain` to control the flow of execution and maintain a shared state across `ChainStep`s, allowing the steps to communicate and pass data to each other seamlessly.\n\nBelow is an illustrative example of how `StateChain` and `ChainStep` can be used together. This example doesn\'t directly implement the classes from the file paths you\'ve provided but abstractly represents how the concept could be implemented based on the provided descriptions.\n\n### Example: Processing User Input\n\nIn this scenario, we want to process user input through a series of steps:\n1. Normalize the input (e.g., trim whitespace, convert to lowercase).\n2. Validate the input (e.g., check if it\'s non-empty after normalization).\n3. Save the valid input to a database.\n\n### ChainStep Implementation\n\nFirst, define the `ChainStep` as an abstract concept where each step has a `run` method to perform its specific task:\n\n```python\nclass ChainStep:\n    def run(self, state):\n        pass  # each step will implement its specific logic\n```\n\nNow, implement concrete steps:\n\n```python\nclass NormalizeInputStep(ChainStep):\n    def run(self, state):\n        input_str = state.get(\'input\', \'\').strip().lower()\n        state[\'normalized_input\'] = input_str\n\nclass ValidateInputStep(ChainStep):\n    def run(self, state):\n        input_str = state.get(\'normalized_input\', \'\')\n        if not input_str:\n            raise ValueError("Input is empty after normalization.")\n        state[\'is_valid\'] = True\n\nclass SaveInputStep(ChainStep):\n    def run(self, state):\n        if state.get(\'is_valid\'):\n            # Assume save_to_db is a function that saves data to your DB\n            save_to_db(state[\'normalized_input\'])\n        else:\n            print("Input is invalid. Skipping save.")\n```\n\n### StateChain Implementation\n\nNext, define the `StateChain` to manage the execution of these steps:\n\n```python\nclass StateChain:\n    def __init__(self):\n        self.steps = []\n        self.state = {}\n\n    def add_step(self, step):\n        self.steps.append(step)\n\n    def execute(self):\n        for step in self.steps:\n            step.run(self.state)\n```\n\n### Leveraging StateChain and ChainStep Together\n\nFinally, create a `StateChain` instance, add the steps, and execute them:\n\n```python\ndef save_to_db(data):\n    print(f"Saving \'{data}\' to database...")\n\nchain = StateChain()\nchain.add_step(NormalizeInputStep())\nchain.add_step(ValidateInputStep())\nchain.add_step(SaveInputStep())\n\nuser_input = "   Hello World!   "\nchain.state[\'input\'] = user_input\ntry:\n    chain.execute()\n    print("Processing completed successfully.")\nexcept ValueError as e:\n    print(f"Error during processing: {e}")\n```\n\n### Explanation\n\n- `ChainStep`: Each step inherits from `ChainStep` and implements the `run` method, specifying its operation. These steps manipulate or use the `state` dictionary provided by the `StateChain` to share data and results.\n- `StateChain`: This class orchestrates the execution, maintaining a shared `state` among all steps. The `add_step` method allows dynamically constructing the execution pipeline, and `execute` runs the steps in order.\n\nThis design ensures a clean separation of responsibilities, where `StateChain` focuses on execution flow and state management, and each `ChainStep` focuses on its specific task. The shared `state` enables flexible communication and data passage between steps, facilitating complex processing pipelines that adapt dynamically based on runtime data.',
#   'role': 'assistant'},
#  {'content': 'this is statechain:\n```python\nfrom typing import Any, Dict, List, Callable\nfrom swarmauri.standard.chains.base.ChainStepBase import ChainStepBase\nfrom swarmauri.core.chains.IChain import IChain\n\nclass StateChain(IChain):\n    """\n    Enhanced to support ChainSteps with return parameters, storing return values as instance state variables.\n    Implements the IChain interface including get_schema_info and remove_step methods.\n    """\n    def __init__(self):\n        self._steps: List[ChainStepBase] = []\n        self._context: Dict[str, Any] = {}\n    \n    def add_step(self, key: str, method: Callable[..., Any], *args, ref: str = None, **kwargs):\n        # Directly store args, kwargs, and optionally a return_key without resolving them\n        step = ChainStepBase(key, method, args=args, kwargs=kwargs, ref=ref)  # Note the use of \'ref\' as \'return_key\'\n        self._steps.append(step)\n    \n    def remove_step(self, step: ChainStepBase) -> None:\n        self._steps = [s for s in self._steps if s.key != step.key]\n    \n    def execute(self, *args, **kwargs) -> Any:\n        # Execute the chain and manage result storage based on return_key\n        for step in self._steps:\n            resolved_args = [self._resolve_placeholders(arg) for arg in step.args]\n            resolved_kwargs = {k: self._resolve_placeholders(v) for k, v in step.kwargs.items() if k != \'ref\'}\n            result = step.method(*resolved_args, **resolved_kwargs)\n            if step.ref:  # step.ref is used here as the return_key analogy\n                print(\'step.ref\', step.ref)\n                resolved_ref = self._resolve_ref(step.ref)\n                print(resolved_ref)\n                self._context[resolved_ref] = result\n        return self._context  # or any specific result you intend to return\n    \n    def _resolve_ref(self, value: Any) -> Any:\n        if isinstance(value, str) and value.startswith(\'${\') and value.endswith(\'}\'):\n            placeholder = value[2:-1]\n            return placeholder\n        return value\n    \n    def _resolve_placeholders(self, value: Any) -> Any:\n        if isinstance(value, str) and value.startswith(\'${\') and value.endswith(\'}\'):\n            placeholder = value[2:-1]\n            return self._context.get(placeholder)\n        return value\n\n    def set_context(self, **kwargs):\n        self._context.update(kwargs)\n    \n    def get_schema_info(self) -> Dict[str, Any]:\n        # Implementing required method from IChain; \n        # Adapt the return structure to your needs\n        return {\n            "steps": [step.key for step in self._steps],\n            "context_keys": list(self._context.keys())\n        }\n```\nthis is chainstep:\n```python\nfrom typing import Any, Callable, List, Dict\nfrom swarmauri.core.chains.IChainStep import IChainStep\nfrom swarmauri.standard.chains.base.ChainStepBase import ChainStepBase\n\nclass ChainStep(ChainStepBase):\n    """\n    Represents a single step within an execution chain.\n    """\n    \n    def __init__(self, \n        key: str, \n        method: Callable, \n        args: List[Any] = None, \n        kwargs: Dict[str, Any] = None, \n        ref: str = None):\n        """\n        Initialize a chain step.\n\n        Args:\n            key (str): Unique key or identifier for the step.\n            method (Callable): The callable object (function or method) to execute in this step.\n            args (List[Any], optional): Positional arguments for the callable.\n            kwargs (Dict[str, Any], optional): Keyword arguments for the callable.\n            ref (str, optional): Reference to another component or context variable, if applicable.\n        """\n        self.key = key\n        self.method = method\n        self.args = args \n        self.kwargs = kwargs\n        self.ref = ref\n        \n\n```\n\n\nall chains below should implement standard/chains/concrete/StateChain and standard/chains/concrete/ChainStepBase ...
#   'role': 'user'},
#  {'content': "Based on the provided `StateChain` and `ChainStep` classes, we can design the `DifferenceAnnotationChain` and `CosineDistanceAnnotationChain` classes to fit within this framework. Here's how these specific chains could be implemented:\n\n### 1. Difference Annotation Chain\n\nThis chain will have three pivotal steps: executing a function `func1`, executing another function `func2`, and then comparing their outputs using `difflib` to produce a difference summary.\n\nFile: `standard/chains/concrete/DifferenceAnnotationChain.py`\n\n```python\nimport difflib\nfrom swarmauri.standard.chains.concrete.StateChain import StateChain\nfrom swarmauri.standard.chains.concrete.ChainStep import ChainStep\n\ndef compare_outputs(func1_output, func2_output):\n    return '\\n'.join(difflib.unified_diff(\n        func1_output.splitlines(), func2_output.splitlines(), lineterm=''))\n\nclass DifferenceAnnotationChain(StateChain):\n    def __init__(self, func1, func2):\n        super().__init__()\n        self.add_step('func1', func1, ref='${func1_output}')  # Assuming func1, func2 returns a string\n        self.add_step('func2', func2, ref='${func2_output}')\n        self.add_step('compare', compare_outputs, '${func1_output}', '${func2_output}', ref='difference')\n\n```\n\n### 2. Cosine Distance Annotation Chain\n\nThis chain will execute two functions and then use a `cosine_distance` function to compare their output vectors. Ensure you have an implementation available for calculating the cosine distance given two vectors.\n\nFile: `standard/chains/concrete/CosineDistanceAnnotationChain.py`\n\n```python\nfrom swarmauri.standard.chains.concrete.StateChain import StateChain\nfrom swarmauri.standard.chains.concrete.ChainStep import ChainStep\n\n# placeholder for cosine_distance implementation\ndef cosine_distance(vector1, vector2):\n    # This function should compute the cosine distance between two vectors\n    pass\n\nclass CosineDistanceAnnotationChain(StateChain):\n    def __init__(self, vector_func1, vector_func2):\n        super().__init__()\n        self.add_step('vector_func1', vector_func1, ref='${vector1}')  # Assuming these funcs return vector\n        self.add_step('vector_func2', vector_func2, ref='${vector2}')\n        self.add_step('compare_vectors', cosine_distance, '${vector1}', '${vector2}', ref='cosine_distance')\n\n```\n\n### Explanation:\n\n- **Step Addition:** The `add_step` method is utilized to add specific steps to the chain. Each step is represented by a `ChainStep` object. The key and method are provided along with input arguments. The `ref` argument is important as it allows the output of steps to be stored within the chain's context (`_context`), which can be used in subsequent steps.\n\n- **State Management:** In both implementations, the `ref` parameter is used in `add_step` calls to define keys under which outputs of steps are stored in the chain’s context. This allows the outputs to be easily passed between steps for comparison.\n\n- **Comparisons:** The last step in each chain is responsible for comparing the outputs of the first two steps. For the `DifferenceAnnotationChain`, the comparison is done using the `difflib.unified_diff` function, which provides a textual difference between the two outputs. For the `CosineDistanceAnnotationChain`, a `cosine_distance` function (need to be implemented separately) is used to calculate the cosine distance between two vectors, indicating how similar they are.\n\nThese implementations are focused on providing a structural approach to sequentially execute functions, pass their results through the chain, and perform a final comparison or analysis step. This structured approach facilitates maintainability, scalability, and readability of the logic that processes data through sequential and dependent operations.",
#   'role': 'assistant'},
#  {'content': "ref doesn't needed to be encapsulated with ${} only args and kwargs variables need to use this",
#   'role': 'user'},
#  {'content': "Given the clarification regarding the `ref` usage, let's adjust the implementations for both the `DifferenceAnnotationChain` and `CosineDistanceAnnotationChain`. In this revised approach, the `ref` does not use the `${}` syntax, and this syntax is reserved solely for `args` and `kwargs` to reference variables stored in the chain's context. Here is how you can implement these chains correctly:\n\n### 1. Difference Annotation Chain\n\nThis chain first executes two functions, captures their outputs, and then compares these outputs using `difflib` for generating a textual difference synopsis.\n\nFile: `standard/chains/concrete/DifferenceAnnotationChain.py`\n\n```python\nimport difflib\nfrom swarmauri.standard.chains.concrete.StateChain import StateChain\nfrom swarmauri.standard.chains.concrete.ChainStep import ChainStep\n\ndef compare_outputs(func1_output, func2_output):\n    # This function compares the outputs using difflib and returns the difference\n    return '\\n'.join(difflib.unified_diff(\n        func1_output.splitlines(), func2_output.splitlines(), lineterm=''))\n\nclass DifferenceAnnotationChain(StateChain):\n    def __init__(self, func1, func2):\n        super().__init__()\n        self.add_step('func1', func1, ref='func1_output')  # Saving output as 'func1_output'\n        self.add_step('func2', func2, ref='func2_output')  # Saving output as 'func2_output'\n        # Using previously stored outputs for comparison\n        self.add_step('compare', compare_outputs, '${func1_output}', '${func2_output}', ref='difference')\n\n```\n\n### 2. Cosine Distance Annotation Chain\n\nIn this chain, two functions are executed to obtain vectors, and these vectors are then used to compute the cosine distance, reflecting the similarity between them.\n\nFile: `standard/chains/concrete/CosineDistanceAnnotationChain.py`\n\n```python\nfrom swarmauri.standard.chains.concrete.StateChain import StateChain\nfrom swarmauri.standard.chains.concrete.ChainStep import ChainStep\n\n# Placeholder - Assume a valid cosine_distance function is available\ndef cosine_distance(vector1, vector2):\n    # Compute the cosine distance between two vectors\n    pass\n\nclass CosineDistanceAnnotationChain(StateChain):\n    def __init__(self, vector_func1, vector_func2):\n        super().__init__()\n        self.add_step('vector_func1', vector_func1, ref='vector1')  # Saving the first vector as 'vector1'\n        self.add_step('vector_func2', vector_func2, ref='vector2')  # Saving the second vector as 'vector2'\n        # Using previously obtained vectors for cosine distance computation\n        self.add_step('compare_vectors', cosine_distance, '${vector1}', '${vector2}', ref='cosine_distance')\n\n```\n\n### Key Points:\n\n- **ref Usage:** The `ref` attribute is correctly used to indicate under what key to store the step's result in the chain's context (without `${}` encapsulation).\n- **Variable Reference:** When passing variables between steps (as inputs to a method), the `${}` syntax is used within `args` and `kwargs` to refer to values stored in the chain's context. This enables dynamic resolution and use of previously stored data.\n- **Flexibility and Dynamism:** This approach underscores the flexibility of the `StateChain` in handling stateful operations and dynamically referencing context-stored variables across different steps in the execution chain.\n\nThese corrections align with your instructions, making use of context variables straightforward and avoiding any unnecessary encapsulation of the `ref` attribute with `${}`.",
#   'role': 'assistant'}]

# %%
rag_assistant.agent.conversation.as_messages()
# Out:
# [{'content': '```swarmauri/core/__init__.py\n\n```\n```swarmauri/core/models/__init__.py\n\n```\n```swarmauri/core/models/IPredict.py\nfrom abc import ABC, abstractmethod\n\nclass IPredict(ABC):\n    """\n    Interface for making predictions with models.\n    """\n\n    @abstractmethod\n    def predict(self, input_data) -> any:\n        """\n        Generate predictions based on the input data provided to the model.\n        """\n        pass\n```\n```swarmauri/core/models/IFit.py\nfrom abc import ABC, abstractmethod\n\nclass IFit(ABC):\n    """\n    Interface for training models.\n    """\n\n    @abstractmethod\n    def fit(self, X_train, y_train, epochs: int, batch_size: int) -> None:\n        """\n        Train the model on the provided dataset.\n        """\n        pass\n```\n```swarmauri/core/models/IModel.py\nfrom abc import ABC, abstractmethod\n\nclass IModel(ABC):\n    """\n    Interface focusing on the basic properties and settings essential for defining models.\n    """\n\n    @property\n    @abstractmethod\n    def model_name(self) -> str:\n        """\n        Get the name of the model.\n        """\n        pass\n\n    @model_name.setter\n    @abstractmethod\n    def model_name(self, value: str) -> None:\n        """\n        Set the name of the model.\n        """\n        pass\n```',
#   'role': 'system'},
#  {'content': 'hi', 'role': 'user'},
#  {'content': "Hello! It seems like you're working with a Python project using an object-oriented approach, specifically with interfaces for machine learning models.\n\nYou have three interfaces defined:\n\n1. `IPredict`: Models that implement this interface should have a `predict` method, which generates predictions based on input data.\n2. `IFit`: Models that implement this interface should have a `fit` method, which trains the model using the provided dataset.\n3. `IModel`: All models should implement this interface, which defines a `model_name` property.\n\nRemember, the purpose of interfaces is to define a contract that ensures a class implements a specific set of methods. In your case, any class that inherits from these interfaces must implement the methods defined within them.\n\nIf you have any questions about how to use these interfaces, or if you're encountering any issues, feel free to ask! I'm here to help.",
#   'role': 'assistant'}]
